# %% [markdown]
# ## Training e Test rete Swin
#
# Addestramento della rete in modalità **pretrained**.

# %% [markdown]
# #### INPUT
# - **Training&Validation**: LARGE DATASET immagini dermoscopiche CON DUPLICATI TRANNE CHE NELLA CLASSE NV
# - **Test**: ISIC 2018 Challenge Test Set senza duplicati

# %% [markdown]
# ## Installation of libraries

# %%
# Install libraries

# !pip install torch torchvision tensorboard
# !pip install barbar
# !pip install torchsummary
# !pip install pytorch-ignite
# !pip install timm
# !pip install opencv-python
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.11/site-packages (0.18.0)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.11/site-packages (2.17.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (1.66.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (3.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorboard) (24.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (69.5.1)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: barbar in /opt/conda/lib/python3.11/site-packages (0.2.1)
# Requirement already satisfied: torchsummary in /opt/conda/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: pytorch-ignite in /opt/conda/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: torch<3,>=1.3 in /opt/conda/lib/python3.11/site-packages (from pytorch-ignite) (2.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from pytorch-ignite) (24.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (4.11.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch<3,>=1.3->pytorch-ignite) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch<3,>=1.3->pytorch-ignite) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch<3,>=1.3->pytorch-ignite) (1.3.0)
# Requirement already satisfied: timm in /opt/conda/lib/python3.11/site-packages (1.0.9)
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (from timm) (2.3.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.11/site-packages (from timm) (0.18.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.11/site-packages (from timm) (0.24.7)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.11/site-packages (from timm) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface_hub->timm) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub->timm) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub->timm) (24.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub->timm) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch->timm) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch->timm) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision->timm) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub->timm) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch->timm) (1.3.0)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.11/site-packages (from opencv-python) (1.26.4)

# %%
import torch
import os
import random
import torchvision
import pandas as pd
import datetime as dt
import torch.nn as nn
import numpy as np
from torchvision import transforms, datasets
from shutil import copyfile, move
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from torch.utils.tensorboard import SummaryWriter
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from barbar import Bar
from torchsummary import summary
from ignite.metrics import Accuracy
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report
from sklearn.metrics import recall_score, precision_score, accuracy_score, f1_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import auc
import timm

from tqdm import tqdm
from sklearn.manifold import TSNE
# Out:
# /opt/conda/lib/python3.11/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
args = {
    # Dataset for segmentation (Kvasir)
    'train_dir_seg': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/train_images',
    'val_dir_seg': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/validation_images',
    'test_dir_seg': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/test_images',

    # Masks for segmentation (Kvasir)
    'mask_dir_train': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/train_mask',
    'mask_dir_val': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/validation_mask',
    'mask_dir_test': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/test_mask',

    # Dataset for classification (Kvasir)
    'train_dir_class': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/train/',
    'val_dir_class': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/validation/',  
    'test_dir_class': '/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/test/',

    'save_dir': 'experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg',
    'num_classes': 8,  # Number of class for classification
    'lambda_multi': 1.0,  # weight for multiclass-loss
    'lambda_bin': 1.0,  # weight for binary-loss
    'batch_size': 144,  # Batch size for training
    'early_stopping': 20,  # Number of epochs for early stopping
    'lr': 0.0001,  # Learning rate
    'alpha': 0.25,  # Specific parameter for the loss weighting
    'device': torch.device("cuda:0" if torch.cuda.is_available() else "cpu"),
}

# %%
if os.path.exists(args['save_dir']):
    raise Exception(f"Sorry, the output dir {args['save_dir']} already exists!")  # error...
os.makedirs(args['save_dir'])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 if os.path.exists(args['save_dir']):
# ----> 2     raise Exception(f"Sorry, the output dir {args['save_dir']} already exists!")  # error...
#       3 os.makedirs(args['save_dir'])
#
# Exception: Sorry, the output dir experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg already exists!

# %%
class Metrics:
    def __init__(self, column_names):
        column_names.insert(0, "time_stamp")
        self.df = pd.DataFrame(columns=column_names)

    def add_row(self, row_list):
        row_list.insert(0, str(dt.datetime.now()))
        # print(row_list)
        self.df.loc[len(self.df)] = row_list

    def save_to_csv(self, filepath):
        self.df.to_csv(filepath, index=False)

    def load(self, filepath):
        # Load data from the CSV file into the DataFrame
        self.df = pd.read_csv(filepath)

    def get_best_value(self, column_name):
        if column_name in self.df.columns:
            return self.df[column_name].max()
        else:
            raise ValueError(f"Column '{column_name}' does not exist in the DataFrame")

    def plot(self, col_names=[], title="", x_label="", y_label="", bottom=None, top=None):
        data2plot = self.df[col_names]
        # ================plot===================
        ax = data2plot.plot(title=title) #figsize=(10,8), 
        ax.set_xlabel(x_label)
        ax.set_ylabel(y_label)
        ax.set_ylim(bottom, top)

# %% [markdown]
# ## Datasets

# %%
# Funzione per contare i file in una cartella per categoria (classificazione)
def count_files_by_category(base_dir, categories):
    count_by_category = {}
    for category in categories:
        dir_path = os.path.join(base_dir, category)
        count_by_category[category] = len(os.listdir(dir_path))
    return count_by_category

# Funzione per contare il numero totale di file in una cartella (segmentazione)
def count_total_files(folder):
    return len(os.listdir(folder))

# Definizione delle classi per la classificazione
categories = ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']

# Conteggio delle immagini di classificazione
train_classification = count_files_by_category(args['train_dir_class'], categories)
val_classification = count_files_by_category(args['val_dir_class'], categories)
test_classification = count_files_by_category(args['test_dir_class'], categories)

# Creazione del DataFrame per la classificazione
df_classification = pd.DataFrame({
    'Training Images': train_classification,
    'Validation Images': val_classification,
    'Test Images': test_classification,
})

# Conteggio totale delle immagini e maschere di segmentazione
train_images_total = count_total_files(args['train_dir_seg'])
train_masks_total = count_total_files(args['mask_dir_train'])
val_images_total = count_total_files(args['val_dir_seg'])
val_masks_total = count_total_files(args['mask_dir_val'])
test_images_total = count_total_files(args['test_dir_seg'])
test_masks_total = count_total_files(args['mask_dir_test'])

# Creazione del DataFrame per la segmentazione
df_segmentation = pd.DataFrame({
    'Total Images': [train_images_total, val_images_total, test_images_total],
    'Total Masks': [train_masks_total, val_masks_total, test_masks_total]
}, index=['Training', 'Validation', 'Test'])

# Visualizzazione dei DataFrame
print("Dataset di classificazione (conteggio per classe)")
display(df_classification)

print("\nDataset di segmentazione (conteggio totale)")
display(df_segmentation)
# Out:
# Dataset di classificazione (conteggio per classe)
#                         Training Images  Validation Images  Test Images
# dyed-lifted-polyps                  375                 75           51
# dyed-resection-margins              375                 75           51
# esophagitis                         375                 75           51
# normal-cecum                        375                 75           51
# normal-pylorus                      375                 75           51
# normal-z-line                       375                 75           51
# polyps                              375                 75           51
# ulcerative-colitis                  375                 75           51
# Dataset di segmentazione (conteggio totale)
#             Total Images  Total Masks
# Training             750          750
# Validation           150          150
# Test                 100          100

# %%
# Definizione della mappatura delle classi binarie dove 1:maligne , 0:benigne
class_mapping = {
    'dyed-lifted-polyps': 1, 'normal-cecum': 0, 'dyed-resection-margins': 1, 'polyps': 1,
    'normal-pylorus': 0, 'normal-z-line': 0, 'esophagitis': 0, 'ulcerative-colitis':1
}

# Custom Dataset per ImageFolder with binary labels
class BinaryImageFolder(datasets.ImageFolder):
    def __init__(self, root, transform=None, binary=True, multi=True):
        super(BinaryImageFolder, self).__init__(root, transform=transform)
        self.binary = binary
        self.multiclass = multi
        #self.dataset = datasets.ImageFolder(root, transform=transform)
        self.idx_to_class = {v: k for k, v in self.class_to_idx.items()}
        print("***Loading:" + root)

    def __getitem__(self, index):
        image, label_multiclass = super(BinaryImageFolder, self).__getitem__(index)
        class_name = self.idx_to_class[label_multiclass]
        label_binaria = class_mapping[class_name]
        return image, label_multiclass, label_binaria


class BinaryOnlyImageFolder(datasets.ImageFolder):
    def __init__(self, root, transform=None, binary=True, multi=False):
        super(BinaryOnlyImageFolder, self).__init__(root, transform=transform)
        self.binary = binary
        self.multiclass = multi
        print("***Loading:" + root)

    def __getitem__(self, index):
        image, label_binary = super(BinaryOnlyImageFolder, self).__getitem__(index)
        return image, -1, label_binary


class MyConcatDataset(ConcatDataset):
    def __init__(self, datasets, binary=True, multi=True):
        super(MyConcatDataset, self).__init__(datasets)
        self.binary = binary
        self.multiclass = multi

# %%
class RandomResize:
    def __init__(self, resize_min=224, resize_max=280):
        self.resize_min = resize_min
        self.resize_max = resize_max

    def __call__(self, img):
        # Randomly choose the resize dimensions
        resize_size = random.randint(self.resize_min, self.resize_max)
        resize_transforms = transforms.Resize(resize_size)
        img = resize_transforms(img)
        return img


train_transforms = transforms.Compose([
    RandomResize(224, 280), # transforms.Resize((224, 280)),  # Aumento delle dimensioni a 224x300
    transforms.RandomCrop((224, 224)),  # Applicazione di RandomCrop
    # transforms.Resize((224, 280)),
    # transforms.CenterCrop((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply([transforms.RandomAffine(degrees=0, translate=(0.1, 0.1))], p=0.5),  

    # La traslazione sarà casuale con un range di +/-10% rispetto alle dimensioni originali
    transforms.RandomApply(transforms=[transforms.RandomRotation(degrees=(-180, 180))], p=0.99),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

val_transforms = transforms.Compose([
    transforms.Resize((224, 280)),  # Aumento delle dimensioni a 224x300
    transforms.RandomCrop((224, 224)),  # Applicazione di RandomCrop
    # transforms.Resize((224, 280)),
    # torchvision.transforms.CenterCrop((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

test_transforms = transforms.Compose([
    transforms.Resize(224), #(224, 300)),  # PERCHE' IL RESIZE E' DIVERSO DAL VAL?
    torchvision.transforms.CenterCrop((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def run_test_datasets():
    # Dataset di classificazione per il training
    train_dataset = BinaryImageFolder(
        args['train_dir_class'], transform=train_transforms, binary=True, multi=True)
    
    # Dataset di classificazione per la validazione
    val_dataset = BinaryImageFolder(
        args['val_dir_class'], transform=val_transforms, binary=True, multi=True)
    
    # Dataset di classificazione per il test
    test_dataset = BinaryImageFolder(
        args['test_dir_class'], transform=test_transforms, binary=True, multi=True)

    # Creare DataLoader per classificazione
    train_loader = DataLoader(train_dataset, batch_size=args['batch_size'], shuffle=True, num_workers=8)
    val_loader = DataLoader(val_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)
    test_loader = DataLoader(test_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)

    return train_loader, val_loader, test_loader

# Esegui la funzione per creare i loader
train_loader, val_loader, test_loader = run_test_datasets()
# Out:
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/train/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/validation/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/test/

# %% [markdown]
# ### Segmentation dataset

# %%
import torchvision.transforms.functional as TF
from PIL import Image

class ComposeTwo(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

class RandomResizeCrop:
    def __init__(self, size=(224,224), resize_min=224, resize_max=280):
        self.size = size
        self.resize_min = resize_min
        self.resize_max = resize_max

    def __call__(self, image, mask):
        new_size = random.randint(self.resize_min, self.resize_max)
        image = TF.resize(image, (new_size, new_size))
        if mask is not None:
            mask = TF.resize(mask, (new_size, new_size), interpolation=Image.NEAREST)
        
        i, j, h, w = transforms.RandomCrop.get_params(image, output_size=self.size)
        image = TF.crop(image, i, j, h, w)
        if mask is not None:
            mask = TF.crop(mask, i, j, h, w)
        return image, mask    

class RandomHorizontalFlip:
    def __init__(self, p=0.5):
        self.p = p

    def __call__(self, image, mask):
        if random.random() < self.p:
            image = TF.hflip(image)
            if mask is not None:
                mask = TF.hflip(mask)
        return image, mask

class RandomAffine:
    def __init__(self, degrees, translate):
        self.degrees = degrees
        self.translate = translate

    def __call__(self, image, mask):
        params = transforms.RandomAffine.get_params(self.degrees, self.translate, None, None, image.size)
        image = TF.affine(image, *params)
        if mask is not None:
            mask = TF.affine(mask, *params)
        return image, mask

class RandomRotation:
    def __init__(self, degrees):
        self.degrees = degrees

    def __call__(self, image, mask):
        angle = random.uniform(self.degrees[0], self.degrees[1])
        image = TF.rotate(image, angle)
        if mask is not None:
            mask = TF.rotate(mask, angle)
        return image, mask

class ToTensorAndNormalize:
    def __init__(self, mean, std):
        self.to_tensor = transforms.ToTensor()
        self.normalize = transforms.Normalize(mean, std)

    def __call__(self, image, mask):
        image = self.to_tensor(image)
        image = self.normalize(image)
        if mask is not None:
            mask = self.to_tensor(mask)
        return image, mask

# Dataset per training e validazione (con sottocartelle)
class CustomSegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        """
        Args:
            image_dir (str): Directory con le immagini di input.
            mask_dir (str): Directory con le maschere di segmentazione.
            transform (callable, optional): Trasformazioni da applicare sia alle immagini di input che alle maschere.
        """
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform

        # Estensioni supportate
        valid_extensions = ('.jpg', '.jpeg', '.png')

        # Cerca immagini e maschere direttamente nella cartella
        self.image_filenames = []
        self.mask_filenames = []

        print(f"Verifica immagini in {image_dir} e maschere in {mask_dir}")
        
        for image_file in os.listdir(image_dir):
            if image_file.endswith(valid_extensions):
                image_path = os.path.join(image_dir, image_file)
                # Le maschere hanno lo stesso nome ed estensione delle immagini
                mask_path = os.path.join(mask_dir, image_file)

                # Aggiungi solo se esistono sia immagine che maschera
                if os.path.exists(mask_path):
                    self.image_filenames.append(image_path)
                    self.mask_filenames.append(mask_path)
                else:
                    print(f"Maschera non trovata per {image_file}, saltata.")

        # Debug: Stampa quante immagini e maschere sono state trovate
        print(f"Immagini trovate: {len(self.image_filenames)}")
        print(f"Maschere trovate: {len(self.mask_filenames)}")

        if len(self.image_filenames) == 0:
            raise ValueError(f"Nessuna immagine trovata nella directory: {image_dir}")
        if len(self.mask_filenames) == 0:
            raise ValueError(f"Nessuna maschera trovata nella directory: {mask_dir}")

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        image_path = self.image_filenames[idx]
        mask_path = self.mask_filenames[idx]

        image = Image.open(image_path).convert("RGB")
        mask = Image.open(mask_path).convert("L")  # Converti la maschera in scala di grigi

        if self.transform:
            image, mask = self.transform(image, mask)

        return image, mask

# Dataset for the test set (no subdirectories by class)
class TestImageSegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = []
        self.masks = []

        # Estensioni valide per le immagini e le maschere
        valid_extensions = ('.jpg', '.jpeg', '.png')

        # Load all images and corresponding masks
        for image_file in os.listdir(image_dir):
            # Only consider valid image files
            if image_file.endswith(valid_extensions):
                image_path = os.path.join(image_dir, image_file)

                # The mask file is expected to have the same name but with .jpg or .png extension
                mask_file = image_file  # Stesso nome per immagine e maschera
                mask_path = os.path.join(mask_dir, mask_file)

                # Append only if both the image and the mask exist
                if os.path.exists(mask_path):
                    self.images.append(image_path)
                    self.masks.append(mask_path)
                else:
                    print(f"Maschera non trovata per {image_file}, saltata.")
        
        # Debug: stampa il numero di immagini e maschere trovate
        print(f"Verifica immagini in {image_dir} e maschere in {mask_dir}")
        print(f"Immagini trovate: {len(self.images)}")
        print(f"Maschere trovate: {len(self.masks)}")

        if len(self.images) == 0:
            raise ValueError(f"Nessuna immagine trovata nella directory: {image_dir}")
        if len(self.masks) == 0:
            raise ValueError(f"Nessuna maschera trovata nella directory: {mask_dir}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = Image.open(self.images[idx]).convert("RGB")
        mask = Image.open(self.masks[idx]).convert("L")  # Convert the mask to grayscale

        if self.transform:
            image, mask = self.transform(image, mask)

        return image, mask

# %%
def run_test_seg_dataset():
    # Definire le trasformazioni
    seg_transform = ComposeTwo([
        RandomResizeCrop((224, 224), resize_min=224, resize_max=280),
        RandomHorizontalFlip(p=0.5),
        RandomAffine(degrees=(-10,10), translate=(0.1, 0.1)),
        RandomRotation(degrees=(-180, 180)),
        ToTensorAndNormalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Dataset di segmentazione per il training
    train_segmentation_dataset = CustomSegmentationDataset(
        args['train_dir_seg'], args['mask_dir_train'], transform=seg_transform)

    # Dataset di segmentazione per la validazione
    val_segmentation_dataset = CustomSegmentationDataset(
        args['val_dir_seg'], args['mask_dir_val'], transform=seg_transform)

    # Dataset di segmentazione per il test (senza sottocartelle e con "_segmentation" nelle maschere)
    test_segmentation_dataset = TestImageSegmentationDataset(
        args['test_dir_seg'], args['mask_dir_test'], transform=seg_transform)

    # Creare DataLoader per segmentazione
    train_segmentation_loader = DataLoader(train_segmentation_dataset, batch_size=args['batch_size'], shuffle=True, num_workers=8)
    val_segmentation_loader = DataLoader(val_segmentation_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)
    test_segmentation_loader = DataLoader(test_segmentation_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)

    # Esegui un esempio per verificare la forma delle immagini e delle maschere
    image, mask = train_segmentation_dataset.__getitem__(0)  # Ottieni il primo esempio dal dataset di training
    print(f"Forma dell'immagine (training): {image.shape}")
    print(f"Forma della maschera (training): {mask.shape}")

    # Verifica se ci sono immagini nel dataset di test
    if len(test_segmentation_dataset) > 0:
        image, mask = test_segmentation_dataset.__getitem__(0)  # Ottieni il primo esempio dal dataset di test
        print(f"Forma dell'immagine (test): {image.shape}")
        print(f"Forma della maschera (test): {mask.shape}")
    else:
        print("Nessuna immagine valida trovata nel dataset di test.")

    return train_segmentation_loader, val_segmentation_loader, test_segmentation_loader

# Esegui la funzione per creare i loader di segmentazione e verifica le forme
train_segmentation_loader, val_segmentation_loader, test_segmentation_loader = run_test_seg_dataset()
# Out:
# Verifica immagini in /home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/train_images e maschere in /home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/train_mask
# Immagini trovate: 750
# Maschere trovate: 750
# Verifica immagini in /home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/validation_images e maschere in /home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/validation_mask
# Immagini trovate: 150
# Maschere trovate: 150
# Verifica immagini in /home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/test_images e maschere in /home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_segmentation/test_mask
# Immagini trovate: 100
# Maschere trovate: 100
# Forma dell'immagine (training): torch.Size([3, 224, 224])
# Forma della maschera (training): torch.Size([1, 224, 224])
# Forma dell'immagine (test): torch.Size([3, 224, 224])
# Forma della maschera (test): torch.Size([1, 224, 224])

# %% [markdown]
# ## Models for classification and segmentation

# %%
from timm.models.layers import SelectAdaptivePool2d
import torch.nn.functional as F

class SwinBase(nn.Module):
    def __init__(self, base_model=None):
        super(SwinBase, self).__init__()
        if base_model is None:
            self.base = timm.create_model('swin_large_patch4_window7_224', pretrained=True)
            self.head_in = self.base.head.in_features
            self.base.head = nn.Identity()
        else:
            self.base = base_model.base
            self.head_in = base_model.head_in

    def load_weights(self, checkpoint_path):
        print("Loading pre-trained:", checkpoint_path)
        self.load_state_dict(torch.load(checkpoint_path))

    def save_weights(self, save_path):
        print("Saving model:", save_path)
        torch.save(self.state_dict(), save_path)


class SwinSeg(SwinBase):
    def __init__(self, base_model=None):
        super(SwinSeg, self).__init__(base_model)

        # Creare un modulo Sequential per l'upsampling
        self.head = nn.Sequential(
            nn.ConvTranspose2d(self.head_in, 512, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.ConvTranspose2d(512, 256, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),

            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.Conv2d(32, 1, kernel_size=1)
        )

    def forward(self, x):
        x = self.base(x)
        x = x.permute(0, 3, 1, 2)  # Diventa [batch, 1536, 7, 7]
        x = self.head(x)
        x = F.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)
        return x

    def convert_to_classification(self, num_classes_multiclass=8, num_classes_binary=2):
        return SwinClassification(base_model=self, num_classes_multiclass=num_classes_multiclass, num_classes_binary=num_classes_binary)


class PermuteDimensions(nn.Module):
    def forward(self, x):
        return x.permute(0, 3, 1, 2)


class SwinClassification(SwinBase):
    def __init__(self, base_model=None, num_classes_multiclass=args['num_classes'], num_classes_binary=2):
        super(SwinClassification, self).__init__(base_model)

        # Definisci la testa del modello usando num_classes_multiclass da args
        self.head = nn.Sequential(
            PermuteDimensions(),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(1),
            nn.Dropout(p=0.0, inplace=False),
            nn.Linear(self.head_in, num_classes_multiclass),
            nn.Linear(num_classes_multiclass, num_classes_binary)
        )

    def forward(self, x):
        x = self.base(x)
        x = self.head[0:4](x)
        x_multiclass = self.head[4](x)
        x_binary = self.head[5](x_multiclass)
        return x_multiclass, x_binary

    def convert_to_segmentation(self):
        return SwinSeg(base_model=self)
# Out:
# /opt/conda/lib/python3.11/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
def run_test():
    input_tensor = torch.randn(1, 3, 224, 224)

    #segmentation_model
    seg_model = SwinSeg()
    seg_model_path = os.path.join(args['save_dir'], 'seg_model.pth')
    out = seg_model(input_tensor)
    print("out seg:", out.shape)

    seg_model.save_weights(seg_model_path)
    seg_model.load_weights(seg_model_path)

    # convert segmentation model into classification model
    cls_model = seg_model.convert_to_classification()
    cls_model_path = os.path.join(args['save_dir'], 'cls_model.pth')
    out1, out2 = cls_model(input_tensor)
    print("out multi:", out1.shape)
    print("out bin:", out2.shape)
    
    cls_model.save_weights(cls_model_path)
    cls_model.load_weights(cls_model_path)

run_test()
# Out:
# out seg: torch.Size([1, 1, 224, 224])
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/seg_model.pth
# Loading pre-trained: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/seg_model.pth
# out multi: torch.Size([1, 8])
# out bin: torch.Size([1, 2])
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/cls_model.pth
# Loading pre-trained: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/cls_model.pth

# %% [markdown]
# ## Training
#
# Compare the training results when three different combinations of data are used.

# %%
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import LambdaLR

device = args['device']

criterion_multi = nn.CrossEntropyLoss()
criterion_binaria = nn.CrossEntropyLoss() #nn.BCEWithLogitsLoss()

# %%
# Funzione per salvare la Confusion Matrix come immagine
def plot_and_save_confusion_matrix(labels, preds, class_names, model_name, save_dir):
    if len(labels) == 0 or len(preds) == 0:
        print(f"Attenzione: Non ci sono dati validi per creare la confusion matrix per il modello {model_name}.")
        return

    conf_matrix = confusion_matrix(labels, preds)
    
    # Controlla se la confusion matrix è vuota
    if conf_matrix.size == 0:
        print(f"Attenzione: La confusion matrix è vuota per il modello {model_name}.")
        return

    plt.figure(figsize=(10, 7))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False, 
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title(f'Confusion Matrix ({model_name})')
    
    # Salva la matrice di confusione come immagine
    cm_path = os.path.join(save_dir, f'confusion_matrix_{model_name}.png')
    plt.savefig(cm_path)
    plt.close()
    print(f"Confusion matrix salvata in: {cm_path}")

# Funzione per tracciare e salvare i grafici di loss e accuracy
def plot_and_save_metrics(metrics, save_dir):
    epochs = metrics['epoch']
    
    # Loss plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, metrics['train_loss_bin'], label='Train Loss Bin')
    plt.plot(epochs, metrics['val_loss_bin'], label='Val Loss Bin')
    plt.plot(epochs, metrics['test_loss_bin'], label='Test Loss Bin')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Binary Loss over Epochs')
    plt.legend()
    loss_plot_path = os.path.join(save_dir, 'loss_plot.png')
    plt.savefig(loss_plot_path)
    plt.close()
    print(f"Loss plot salvato in: {loss_plot_path}")

    # Accuracy plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, metrics['train_acc_bin'], label='Train Acc Bin')
    plt.plot(epochs, metrics['val_acc_bin'], label='Val Acc Bin')
    plt.plot(epochs, metrics['test_acc_bin'], label='Test Acc Bin')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Binary Accuracy over Epochs')
    plt.legend()
    acc_plot_path = os.path.join(save_dir, 'accuracy_plot.png')
    plt.savefig(acc_plot_path)
    plt.close()
    print(f"Accuracy plot salvato in: {acc_plot_path}")

# %%
# Funzioni di training e validazione
def train_one_epoch(model, train_loader, optimizer, device):
    print('Start training...')
    model.train()
    running_loss_multi = 0.0
    running_loss_binaria = 0.0
    correct_multi = torch.tensor(0).to(device)
    correct_bin = torch.tensor(0).to(device)
    total = 0

    for inputs, labels_multi, labels_bin in train_loader:
        inputs, labels_multi = inputs.to(device), labels_multi.to(device)
        labels_bin = labels_bin.to(device)

        optimizer.zero_grad()
        multiclass_output, binary_output = model(inputs)

        comb_loss = 0
        # Loss multi-classe
        if train_loader.dataset.multiclass:
            loss_multi = criterion_multi(multiclass_output, labels_multi)
            comb_loss += args["lambda_multi"] * loss_multi 

        # Loss binaria
        if train_loader.dataset.binary:
            loss_binaria = criterion_binaria(binary_output, labels_bin)
            comb_loss += args["lambda_bin"] * loss_binaria

        comb_loss.backward()
        optimizer.step()

        # Accumulate loss and accuracy
        if train_loader.dataset.multiclass:
            running_loss_multi += loss_multi.item()
            _, predicted_multi = torch.max(multiclass_output, dim=1)
            correct_multi += (predicted_multi.view(labels_multi.size()).data == labels_multi.data).sum()

        if train_loader.dataset.binary:
            running_loss_binaria += loss_binaria.item()
            _, predicted_bin = torch.max(binary_output, dim=1)
            correct_bin += (predicted_bin.view(labels_bin.size()).data == labels_bin.data).sum()

        total += labels_multi.size(0)

    train_loss_multi = running_loss_multi / len(train_loader)
    train_loss_binaria = running_loss_binaria / len(train_loader)
    train_acc_multi = correct_multi / total
    train_acc_bin = correct_bin / total
    return train_loss_multi, train_loss_binaria, train_acc_multi.cpu().item(), train_acc_bin.cpu().item()

def validate(model, val_loader, device):
    print('Start validation...')
    model.eval()
    running_loss_multi = 0.0
    running_loss_binaria = 0.0
    correct_multi = torch.tensor(0).to(device)
    correct_bin = torch.tensor(0).to(device)
    total_multi = 0
    total_bin = 0
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for inputs, labels_multi, labels_bin in val_loader:
            inputs, labels_multi = inputs.to(device), labels_multi.to(device)
            labels_bin = labels_bin.to(device)

            multiclass_output, binary_output = model(inputs)

            # Loss multi-classe
            if val_loader.dataset.multiclass:
                loss_multi = criterion_multi(multiclass_output, labels_multi)
                running_loss_multi += loss_multi.item()
                _, predicted_multi = torch.max(multiclass_output, dim=1)
                correct_multi += (predicted_multi.view(labels_multi.size()).data == labels_multi.data).sum()
                total_multi += labels_multi.size(0)
                all_labels.extend(labels_multi.cpu().numpy())
                all_predictions.extend(predicted_multi.cpu().numpy())

            # Loss binaria
            if val_loader.dataset.binary:
                loss_binaria = criterion_binaria(binary_output, labels_bin)
                running_loss_binaria += loss_binaria.item()
                _, predicted_bin = torch.max(binary_output, dim=1)
                correct_bin += (predicted_bin.view(labels_bin.size()).data == labels_bin.data).sum()
                total_bin += labels_bin.size(0)

    val_loss_multi = running_loss_multi / total_multi if total_multi > 0 else 0
    val_loss_binaria = running_loss_binaria / total_bin if total_bin > 0 else 0

    # Verifica se val_acc_multi_filtered e val_acc_bin sono tensori prima di usare .cpu().item()
    if isinstance(correct_multi, torch.Tensor):
        val_acc_multi_filtered = correct_multi / total_multi if total_multi > 0 else 0
        val_acc_multi_filtered = val_acc_multi_filtered.cpu().item() if torch.is_tensor(val_acc_multi_filtered) else val_acc_multi_filtered
    else:
        val_acc_multi_filtered = correct_multi / total_multi if total_multi > 0 else correct_multi

    if isinstance(correct_bin, torch.Tensor):
        val_acc_bin = correct_bin / total_bin if total_bin > 0 else 0
        val_acc_bin = val_acc_bin.cpu().item() if torch.is_tensor(val_acc_bin) else val_acc_bin
    else:
        val_acc_bin = correct_bin / total_bin if total_bin > 0 else correct_bin

    return val_loss_multi, val_loss_binaria, val_acc_multi_filtered, val_acc_bin, all_labels, all_predictions

# %%
# Funzione principale per il training binario
def run_binary_training():
    # Utilizza i dataset di classificazione definiti in args
    train_dataset = BinaryImageFolder(
        args['train_dir_class'], transform=train_transforms, binary=True, multi=False)
    
    val_dataset = BinaryImageFolder(
        args['val_dir_class'], transform=val_transforms, binary=True, multi=False)
    
    test_dataset = BinaryImageFolder(
        args['test_dir_class'], transform=test_transforms, binary=True, multi=False)
    
    # Creazione dei DataLoader per training, validazione e test
    train_loader = DataLoader(train_dataset, batch_size=args['batch_size'], shuffle=True, num_workers=8)
    val_loader = DataLoader(val_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)
    test_loader = DataLoader(test_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)
    
    print("\nNumero di esempi nel dataset di training:", len(train_dataset))
    
    # Inizializza le metriche, il modello, l'ottimizzatore, ecc.
    metrics = Metrics(["epoch", "lr", 
                       "train_loss_mult", "train_loss_bin", 
                       "train_acc_multi", "train_acc_bin", 
                       "val_loss_multi", "val_loss_bin", 
                       "val_acc_multi", "val_acc_bin",
                       "test_loss_multi", "test_loss_bin",
                       "test_acc_multi", "test_acc_bin",
                       "best_val_acc"])
    
    # Non caricare il modello di segmentazione pre-addestrato, inizializza un nuovo modello di classificazione
    print("Inizializzazione di un nuovo modello di classificazione...")
    model = SwinClassification(num_classes_multiclass=args['num_classes'], num_classes_binary=2)  # Modello di classificazione
    
    model = model.to(args['device'])
    
    optimizer = optim.Adam(model.parameters(), lr=args['lr'])
    lambda_lr = lambda epoch: 0.95 ** epoch
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)
    
    best_val_acc = 0
    best_test_acc_bin = 0  # Per tracciare il miglior test acc binario
    
    for epoch in range(100):  # Imposta il numero di epoche
        # Fase di training
        train_loss_multi, train_loss_binaria, train_acc, train_acc_bin = train_one_epoch(
            model, train_loader, optimizer, args['device'])
        
        # Fase di validazione
        val_loss_multi, val_loss_binaria, val_acc_multi, val_acc_bin, val_labels, val_preds = validate(
            model, val_loader, args['device'])
        
        # Fase di test
        test_loss_multi, test_loss_binaria, test_acc_multi, test_acc_bin, test_labels, test_preds = validate(
            model, test_loader, args['device'])
        
        scheduler.step()
        
        print(f'Epoca {epoch+1}, Loss Train Bin: {train_loss_binaria:.4f}, '
              f'Acc Train Bin: {train_acc_bin:.4f}, Loss Val Bin: {val_loss_binaria:.4f}, '
              f'Acc Val Bin: {val_acc_bin:.4f}, Loss Test Bin: {test_loss_binaria:.4f}, '
              f'Acc Test Bin: {test_acc_bin:.4f}')
        
        # Salva il modello se l'accuratezza di validazione binaria è migliorata
        if val_acc_bin > best_val_acc:
            print("Miglior Acc Val Bin, salvataggio del modello...")
            best_val_acc = val_acc_bin
            torch.save(model.state_dict(), os.path.join(args['save_dir'], f'model_best_val_bin.pt'))
        
        # Salva il modello se l'accuratezza di test binaria è migliorata
        if test_acc_bin > best_test_acc_bin:
            print("Miglior Acc Test Bin, salvataggio del modello...")
            best_test_acc_bin = test_acc_bin
            torch.save(model.state_dict(), os.path.join(args['save_dir'], f'model_best_test_bin.pt'))
        
        # Salva il modello ad ogni epoca
        torch.save(model.state_dict(), os.path.join(args['save_dir'], f'model_last_bin.pt'))
        
        # Aggiungi i risultati alle metriche
        lr = optimizer.param_groups[0]["lr"]
        metrics.add_row([
            epoch+1, 
            lr, 
            train_loss_multi, 
            train_loss_binaria, 
            train_acc, 
            train_acc_bin, 
            val_loss_multi,
            val_loss_binaria,
            val_acc_multi,
            val_acc_bin,
            test_loss_multi, 
            test_loss_binaria, 
            test_acc_multi, 
            test_acc_bin,
            best_val_acc
        ])
        metrics.save_to_csv(os.path.join(args['save_dir'], f"metrics_bin5.csv"))
    
    # Salva i grafici delle metriche di loss e accuracy
    metrics_data = pd.read_csv(os.path.join(args['save_dir'], "metrics_bin5.csv"))
    plot_and_save_metrics(metrics_data, args['save_dir'])

    # Salva la confusion matrix
    class_names = ['Benign', 'Malignant']  # Sostituisci con i nomi delle classi
    #plot_and_save_confusion_matrix(test_labels, test_preds, class_names, "best_test_bin", args['save_dir'])
    plot_and_save_confusion_matrix(val_labels, val_preds, class_names, "best_val_bin", args['save_dir'])
    
    print("Training completato.")

# Esegui la funzione per il training binario usando un nuovo modello di classificazione
run_binary_training()
# Out:
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/train/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/validation/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/test/
#
# Numero di esempi nel dataset di training: 3000
# Inizializzazione di un nuovo modello di classificazione...
# Start training...
# Start validation...
# Start validation...
# Epoca 1, Loss Train Bin: 0.2176, Acc Train Bin: 0.9043, Loss Val Bin: 0.0005, Acc Val Bin: 0.9800, Loss Test Bin: 0.0006, Acc Test Bin: 0.9625
# Miglior Acc Val Bin, salvataggio del modello...
# Miglior Acc Test Bin, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 2, Loss Train Bin: 0.0663, Acc Train Bin: 0.9763, Loss Val Bin: 0.0001, Acc Val Bin: 0.9933, Loss Test Bin: 0.0002, Acc Test Bin: 0.9925
# Miglior Acc Val Bin, salvataggio del modello...
# Miglior Acc Test Bin, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 3, Loss Train Bin: 0.0427, Acc Train Bin: 0.9863, Loss Val Bin: 0.0006, Acc Val Bin: 0.9733, Loss Test Bin: 0.0004, Acc Test Bin: 0.9900
# Start training...
# Start validation...
# Start validation...
# Epoca 4, Loss Train Bin: 0.0447, Acc Train Bin: 0.9837, Loss Val Bin: 0.0006, Acc Val Bin: 0.9717, Loss Test Bin: 0.0004, Acc Test Bin: 0.9875
# Start training...
# Start validation...
# Start validation...
# Epoca 5, Loss Train Bin: 0.0306, Acc Train Bin: 0.9887, Loss Val Bin: 0.0004, Acc Val Bin: 0.9817, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 6, Loss Train Bin: 0.0180, Acc Train Bin: 0.9957, Loss Val Bin: 0.0001, Acc Val Bin: 0.9917, Loss Test Bin: 0.0002, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 7, Loss Train Bin: 0.0224, Acc Train Bin: 0.9913, Loss Val Bin: 0.0005, Acc Val Bin: 0.9867, Loss Test Bin: 0.0004, Acc Test Bin: 0.9900
# Start training...
# Start validation...
# Start validation...
# Epoca 8, Loss Train Bin: 0.0089, Acc Train Bin: 0.9970, Loss Val Bin: 0.0002, Acc Val Bin: 0.9950, Loss Test Bin: 0.0003, Acc Test Bin: 0.9900
# Miglior Acc Val Bin, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 9, Loss Train Bin: 0.0120, Acc Train Bin: 0.9970, Loss Val Bin: 0.0003, Acc Val Bin: 0.9850, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 10, Loss Train Bin: 0.0056, Acc Train Bin: 0.9987, Loss Val Bin: 0.0002, Acc Val Bin: 0.9900, Loss Test Bin: 0.0002, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 11, Loss Train Bin: 0.0074, Acc Train Bin: 0.9967, Loss Val Bin: 0.0001, Acc Val Bin: 0.9933, Loss Test Bin: 0.0002, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 12, Loss Train Bin: 0.0143, Acc Train Bin: 0.9953, Loss Val Bin: 0.0007, Acc Val Bin: 0.9850, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 13, Loss Train Bin: 0.0199, Acc Train Bin: 0.9930, Loss Val Bin: 0.0001, Acc Val Bin: 0.9900, Loss Test Bin: 0.0002, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 14, Loss Train Bin: 0.0118, Acc Train Bin: 0.9960, Loss Val Bin: 0.0002, Acc Val Bin: 0.9900, Loss Test Bin: 0.0001, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 15, Loss Train Bin: 0.0049, Acc Train Bin: 0.9987, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0002, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 16, Loss Train Bin: 0.0067, Acc Train Bin: 0.9977, Loss Val Bin: 0.0003, Acc Val Bin: 0.9867, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Miglior Acc Test Bin, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 17, Loss Train Bin: 0.0047, Acc Train Bin: 0.9987, Loss Val Bin: 0.0004, Acc Val Bin: 0.9900, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 18, Loss Train Bin: 0.0020, Acc Train Bin: 0.9997, Loss Val Bin: 0.0001, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 19, Loss Train Bin: 0.0008, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 20, Loss Train Bin: 0.0009, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 21, Loss Train Bin: 0.0010, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9950, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 22, Loss Train Bin: 0.0018, Acc Train Bin: 0.9990, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 23, Loss Train Bin: 0.0012, Acc Train Bin: 0.9997, Loss Val Bin: 0.0005, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 24, Loss Train Bin: 0.0007, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0004, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 25, Loss Train Bin: 0.0025, Acc Train Bin: 0.9993, Loss Val Bin: 0.0003, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 26, Loss Train Bin: 0.0034, Acc Train Bin: 0.9983, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0004, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 27, Loss Train Bin: 0.0015, Acc Train Bin: 0.9993, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0002, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 28, Loss Train Bin: 0.0057, Acc Train Bin: 0.9977, Loss Val Bin: 0.0004, Acc Val Bin: 0.9917, Loss Test Bin: 0.0004, Acc Test Bin: 0.9925
# Start training...
# Start validation...
# Start validation...
# Epoca 29, Loss Train Bin: 0.0047, Acc Train Bin: 0.9983, Loss Val Bin: 0.0002, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 30, Loss Train Bin: 0.0032, Acc Train Bin: 0.9987, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 31, Loss Train Bin: 0.0047, Acc Train Bin: 0.9990, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 32, Loss Train Bin: 0.0021, Acc Train Bin: 0.9990, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 33, Loss Train Bin: 0.0009, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 34, Loss Train Bin: 0.0038, Acc Train Bin: 0.9987, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 35, Loss Train Bin: 0.0007, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 36, Loss Train Bin: 0.0020, Acc Train Bin: 0.9993, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 37, Loss Train Bin: 0.0060, Acc Train Bin: 0.9983, Loss Val Bin: 0.0002, Acc Val Bin: 0.9900, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 38, Loss Train Bin: 0.0028, Acc Train Bin: 0.9993, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 39, Loss Train Bin: 0.0015, Acc Train Bin: 0.9993, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 40, Loss Train Bin: 0.0014, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 41, Loss Train Bin: 0.0018, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 42, Loss Train Bin: 0.0011, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 43, Loss Train Bin: 0.0005, Acc Train Bin: 1.0000, Loss Val Bin: 0.0001, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 44, Loss Train Bin: 0.0007, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 45, Loss Train Bin: 0.0016, Acc Train Bin: 0.9993, Loss Val Bin: 0.0002, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 46, Loss Train Bin: 0.0004, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 47, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 48, Loss Train Bin: 0.0005, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 49, Loss Train Bin: 0.0027, Acc Train Bin: 0.9993, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 50, Loss Train Bin: 0.0010, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 51, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 52, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 53, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 54, Loss Train Bin: 0.0018, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 55, Loss Train Bin: 0.0009, Acc Train Bin: 0.9997, Loss Val Bin: 0.0004, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 56, Loss Train Bin: 0.0004, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 57, Loss Train Bin: 0.0005, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 58, Loss Train Bin: 0.0026, Acc Train Bin: 0.9990, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0002, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 59, Loss Train Bin: 0.0012, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 60, Loss Train Bin: 0.0022, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9867, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 61, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9950, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 62, Loss Train Bin: 0.0017, Acc Train Bin: 0.9990, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 63, Loss Train Bin: 0.0035, Acc Train Bin: 0.9993, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 64, Loss Train Bin: 0.0013, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 65, Loss Train Bin: 0.0013, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 66, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 67, Loss Train Bin: 0.0005, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 68, Loss Train Bin: 0.0004, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 69, Loss Train Bin: 0.0004, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 70, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 71, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 72, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 73, Loss Train Bin: 0.0005, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 74, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 75, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 76, Loss Train Bin: 0.0016, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 77, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 78, Loss Train Bin: 0.0006, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 79, Loss Train Bin: 0.0004, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 80, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 81, Loss Train Bin: 0.0014, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 82, Loss Train Bin: 0.0013, Acc Train Bin: 0.9993, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 83, Loss Train Bin: 0.0005, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 84, Loss Train Bin: 0.0004, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 85, Loss Train Bin: 0.0005, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 86, Loss Train Bin: 0.0015, Acc Train Bin: 0.9993, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 87, Loss Train Bin: 0.0004, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 88, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 89, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 90, Loss Train Bin: 0.0006, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 91, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 92, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 93, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9900, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 94, Loss Train Bin: 0.0008, Acc Train Bin: 0.9997, Loss Val Bin: 0.0004, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 95, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 96, Loss Train Bin: 0.0007, Acc Train Bin: 0.9997, Loss Val Bin: 0.0003, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 97, Loss Train Bin: 0.0001, Acc Train Bin: 1.0000, Loss Val Bin: 0.0004, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 98, Loss Train Bin: 0.0005, Acc Train Bin: 0.9997, Loss Val Bin: 0.0002, Acc Val Bin: 0.9917, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 99, Loss Train Bin: 0.0002, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9883, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Start training...
# Start validation...
# Start validation...
# Epoca 100, Loss Train Bin: 0.0003, Acc Train Bin: 1.0000, Loss Val Bin: 0.0003, Acc Val Bin: 0.9933, Loss Test Bin: 0.0003, Acc Test Bin: 0.9950
# Loss plot salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/loss_plot.png
# Accuracy plot salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/accuracy_plot.png
# Attenzione: Non ci sono dati validi per creare la confusion matrix per il modello best_val_bin.
# Training completato.

# %% [markdown]
# ## Training Multiclass without class Other
#
# After loading the binary pretrained model 'model_last_bin.pt', trained using only all the datasets with binary classes, we fine-tune the model with two loss functions for binary and multi-classes clssification.

# %%
# Funzioni di training e validazione
def train_one_epoch_multi(model, train_loader, optimizer, device):
    print('Start training...')
    model.train()
    running_loss_multi = 0.0
    running_loss_binaria = 0.0
    correct_multi = torch.tensor(0).to(device)
    correct_bin = torch.tensor(0).to(device)
    total = 0

    for inputs, labels_multi, labels_bin in train_loader:
        inputs, labels_multi = inputs.to(device), labels_multi.to(device)
        labels_bin = labels_bin.to(device)

        optimizer.zero_grad()
        multiclass_output, binary_output = model(inputs)

        comb_loss = 0
        # Loss multi-classe
        if train_loader.dataset.multiclass:
            loss_multi = criterion_multi(multiclass_output, labels_multi)
            comb_loss += args["lambda_multi"] * loss_multi 

        # Loss binaria
        if train_loader.dataset.binary:
            loss_binaria = criterion_binaria(binary_output, labels_bin)
            comb_loss += args["lambda_bin"] * loss_binaria

        comb_loss.backward()
        optimizer.step()

        # Accumulate loss and accuracy
        if train_loader.dataset.multiclass:
            running_loss_multi += loss_multi.item()
            _, predicted_multi = torch.max(multiclass_output, dim=1)
            correct_multi += (predicted_multi.view(labels_multi.size()).data == labels_multi.data).sum()

        if train_loader.dataset.binary:
            running_loss_binaria += loss_binaria.item()
            _, predicted_bin = torch.max(binary_output, dim=1)
            correct_bin += (predicted_bin.view(labels_bin.size()).data == labels_bin.data).sum()

        total += labels_multi.size(0)

    train_loss_multi = running_loss_multi / len(train_loader)
    train_loss_binaria = running_loss_binaria / len(train_loader)
    train_acc_multi = correct_multi / total
    train_acc_bin = correct_bin / total
    return train_loss_multi, train_loss_binaria, train_acc_multi, train_acc_bin

def validate_multi(model, val_loader, device):
    print('Start validation...')
    model.eval()
    running_loss_multi = 0.0
    running_loss_binaria = 0.0
    correct_multi = torch.tensor(0).to(device)
    correct_bin = torch.tensor(0).to(device)
    total_multi = 0
    total_bin = 0
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for inputs, labels_multi, labels_bin in val_loader:
            inputs, labels_multi = inputs.to(device), labels_multi.to(device)
            labels_bin = labels_bin.to(device)

            multiclass_output, binary_output = model(inputs)

            # Loss multi-classe
            if val_loader.dataset.multiclass:
                loss_multi = criterion_multi(multiclass_output, labels_multi)
                running_loss_multi += loss_multi.item()
                _, predicted_multi = torch.max(multiclass_output, dim=1)
                correct_multi += (predicted_multi.view(labels_multi.size()).data == labels_multi.data).sum()
                total_multi += labels_multi.size(0)
                all_labels.extend(labels_multi.cpu().numpy())
                all_predictions.extend(predicted_multi.cpu().numpy())

            # Loss binaria
            if val_loader.dataset.binary:
                loss_binaria = criterion_binaria(binary_output, labels_bin)
                running_loss_binaria += loss_binaria.item()
                _, predicted_bin = torch.max(binary_output, dim=1)
                correct_bin += (predicted_bin.view(labels_bin.size()).data == labels_bin.data).sum()
                total_bin += labels_bin.size(0)

    val_loss_multi = running_loss_multi / total_multi if total_multi > 0 else 0
    val_loss_binaria = running_loss_binaria / total_bin if total_bin > 0 else 0

    val_acc_multi_filtered = correct_multi / total_multi if total_multi > 0 else 0
    val_acc_bin = correct_bin / total_bin if total_bin > 0 else 0

    # Calcola la matrice di confusione
    conf_matrix = confusion_matrix(all_labels, all_predictions)

    return val_loss_multi, val_loss_binaria, val_acc_multi_filtered, val_acc_bin, conf_matrix

def to_cpu(x):
    # Controlla se è un tensore e se sì lo sposta sulla CPU e ottiene il valore scalare
    return x.cpu().item() if isinstance(x, torch.Tensor) else x

# Funzione per tracciare e salvare i grafici di loss e accuracy
def plot_and_save_metrics_multi(metrics_data, save_dir):
    epochs = metrics_data['epoch']

    # Loss plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, metrics_data['train_loss_mult'], label='Train Loss')
    plt.plot(epochs, metrics_data['val_loss_multi'], label='Validation Loss')
    plt.plot(epochs, metrics_data['test_loss_multi'], label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Multiclass Loss over Epochs')
    plt.legend()
    loss_plot_path = os.path.join(save_dir, 'multiclass_loss_plot.png')
    plt.savefig(loss_plot_path)
    plt.close()
    print(f"Loss plot salvato in: {loss_plot_path}")

    # Accuracy plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, metrics_data['train_acc_multi'], label='Train Accuracy')
    plt.plot(epochs, metrics_data['val_acc_multi'], label='Validation Accuracy')
    plt.plot(epochs, metrics_data['test_acc_multi'], label='Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Multiclass Accuracy over Epochs')
    plt.legend()
    acc_plot_path = os.path.join(save_dir, 'multiclass_accuracy_plot.png')
    plt.savefig(acc_plot_path)
    plt.close()
    print(f"Accuracy plot salvato in: {acc_plot_path}")

# %%
# Funzione principale per il training multi-classe
def run_multiclass_training():
    # Utilizza i dataset di classificazione definiti in args per multi-classe
    train_dataset = BinaryImageFolder(
        args['train_dir_class'], transform=train_transforms, binary=False, multi=True)
    
    val_dataset = BinaryImageFolder(
        args['val_dir_class'], transform=val_transforms, binary=False, multi=True)
    
    test_dataset = BinaryImageFolder(
        args['test_dir_class'], transform=test_transforms, binary=False, multi=True)
    
    # Creazione dei DataLoader per training, validazione e test
    train_loader = DataLoader(train_dataset, batch_size=args['batch_size'], shuffle=True, num_workers=8)
    val_loader = DataLoader(val_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)
    test_loader = DataLoader(test_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)

    print("\nNumero di esempi nel dataset di training:", len(train_dataset))

    # Inizializza le metriche
    metrics = Metrics(["epoch", "lr", 
                       "train_loss_mult", "train_loss_bin", 
                       "train_acc_multi", "train_acc_bin", 
                       "val_loss_multi", "val_loss_bin", 
                       "val_acc_multi", "val_acc_bin",
                       "test_loss_multi", "test_loss_bin",
                       "test_acc_multi", "test_acc_bin",
                       "best_val_acc", "conf_matrix"])

    print("Creazione del nuovo modello...")
    model = SwinClassification(num_classes_multiclass=args['num_classes'], 
                               num_classes_binary=2)

    # Caricamento del modello pre-addestrato (binario)
    model_path = os.path.join(args['save_dir'], 'model_best_val_bin.pt')
    model.load_state_dict(torch.load(model_path, map_location=args['device']))

    model = model.to(args['device'])
    optimizer = optim.Adam(model.parameters(), lr=args['lr'])
    lambda_lr = lambda epoch: 0.95 ** epoch
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)

    best_val_acc_multi = 0  # Variabile per tracciare il miglior valore di accuratezza di validazione multi-classe
    
    for epoch in range(100):  # Imposta il numero di epoche
        # Fase di training (multi-classe)
        train_loss_multi, train_loss_binaria, train_acc_multi, train_acc_bin = train_one_epoch_multi(
            model, train_loader, optimizer, args['device'])
        
        # Fase di validazione (multi-classe)
        val_loss_multi, val_loss_binaria, val_acc_multi, val_acc_bin, val_conf_matrix = validate_multi(
            model, val_loader, args['device'])

        # Fase di test (multi-classe)
        test_loss_multi, test_loss_binaria, test_acc_multi, test_acc_bin, test_conf_matrix = validate_multi(
            model, test_loader, args['device'])
        
        scheduler.step()

        # Output dei risultati
        print(f'Epoca {epoch+1}, Loss Train Multi: {train_loss_multi:.4f}, '
              f'Acc Train Multi: {to_cpu(train_acc_multi):.4f}, Loss Val Multi: {val_loss_multi:.4f}, '
              f'Acc Val Multi: {to_cpu(val_acc_multi):.4f}, Loss Test Multi: {test_loss_multi:.4f}, '
              f'Acc Test Multi: {to_cpu(test_acc_multi):.4f}')
        
        # Salva il modello se l'accuratezza di validazione multi-classe è migliorata
        if val_acc_multi > best_val_acc_multi:
            print("Miglior acc val multi-classe, salvataggio del modello...")
            best_val_acc_multi = to_cpu(val_acc_multi)
            torch.save(model.state_dict(), os.path.join(args['save_dir'], f'model_best_val_bin+multi.pt'))
        
        # Salva il modello ad ogni epoca
        torch.save(model.state_dict(), os.path.join(args['save_dir'], f'model_last_bin+multi.pt'))

        # Aggiorna le metriche
        lr = optimizer.param_groups[0]["lr"]
        metrics.add_row([
            epoch+1, 
            lr, 
            train_loss_multi, 
            train_loss_binaria, 
            to_cpu(train_acc_multi),   # Conversione con funzione helper
            to_cpu(train_acc_bin),     # Conversione con funzione helper
            val_loss_multi,
            val_loss_binaria,
            to_cpu(val_acc_multi),     # Conversione con funzione helper
            to_cpu(val_acc_bin),       # Conversione con funzione helper
            test_loss_multi, 
            test_loss_binaria, 
            to_cpu(test_acc_multi),    # Conversione con funzione helper
            to_cpu(test_acc_bin),      # Conversione con funzione helper
            best_val_acc_multi,
            f"{test_conf_matrix}",
        ])
        metrics.save_to_csv(os.path.join(args['save_dir'], f"metrics_bin+multi5.csv"))

    # Salva i plot di loss e accuracy
    metrics_data = pd.read_csv(os.path.join(args['save_dir'], "metrics_bin+multi5.csv"))
    plot_and_save_metrics_multi(metrics_data, args['save_dir'])
    
    print("Training completato.")

# Esegui la funzione per il training multi-classe
run_multiclass_training()
# Out:
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/train/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/validation/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/test/
#
# Numero di esempi nel dataset di training: 3000
# Creazione del nuovo modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 1, Loss Train Multi: 1.3647, Acc Train Multi: 0.6460, Loss Val Multi: 0.0027, Acc Val Multi: 0.8733, Loss Test Multi: 0.0024, Acc Test Multi: 0.8725
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 2, Loss Train Multi: 0.2576, Acc Train Multi: 0.9043, Loss Val Multi: 0.0019, Acc Val Multi: 0.9067, Loss Test Multi: 0.0017, Acc Test Multi: 0.9175
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 3, Loss Train Multi: 0.1881, Acc Train Multi: 0.9250, Loss Val Multi: 0.0012, Acc Val Multi: 0.9283, Loss Test Multi: 0.0015, Acc Test Multi: 0.9275
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 4, Loss Train Multi: 0.1640, Acc Train Multi: 0.9403, Loss Val Multi: 0.0014, Acc Val Multi: 0.9183, Loss Test Multi: 0.0013, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 5, Loss Train Multi: 0.1361, Acc Train Multi: 0.9487, Loss Val Multi: 0.0012, Acc Val Multi: 0.9300, Loss Test Multi: 0.0015, Acc Test Multi: 0.9225
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 6, Loss Train Multi: 0.1073, Acc Train Multi: 0.9593, Loss Val Multi: 0.0018, Acc Val Multi: 0.9133, Loss Test Multi: 0.0016, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 7, Loss Train Multi: 0.0945, Acc Train Multi: 0.9690, Loss Val Multi: 0.0015, Acc Val Multi: 0.9317, Loss Test Multi: 0.0016, Acc Test Multi: 0.9350
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 8, Loss Train Multi: 0.0972, Acc Train Multi: 0.9633, Loss Val Multi: 0.0018, Acc Val Multi: 0.9150, Loss Test Multi: 0.0018, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 9, Loss Train Multi: 0.0941, Acc Train Multi: 0.9653, Loss Val Multi: 0.0012, Acc Val Multi: 0.9333, Loss Test Multi: 0.0015, Acc Test Multi: 0.9325
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 10, Loss Train Multi: 0.0713, Acc Train Multi: 0.9733, Loss Val Multi: 0.0013, Acc Val Multi: 0.9283, Loss Test Multi: 0.0016, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 11, Loss Train Multi: 0.0590, Acc Train Multi: 0.9793, Loss Val Multi: 0.0014, Acc Val Multi: 0.9350, Loss Test Multi: 0.0018, Acc Test Multi: 0.9375
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 12, Loss Train Multi: 0.0560, Acc Train Multi: 0.9830, Loss Val Multi: 0.0016, Acc Val Multi: 0.9333, Loss Test Multi: 0.0020, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 13, Loss Train Multi: 0.0433, Acc Train Multi: 0.9847, Loss Val Multi: 0.0014, Acc Val Multi: 0.9333, Loss Test Multi: 0.0019, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 14, Loss Train Multi: 0.0416, Acc Train Multi: 0.9853, Loss Val Multi: 0.0016, Acc Val Multi: 0.9300, Loss Test Multi: 0.0021, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 15, Loss Train Multi: 0.0395, Acc Train Multi: 0.9863, Loss Val Multi: 0.0017, Acc Val Multi: 0.9367, Loss Test Multi: 0.0018, Acc Test Multi: 0.9425
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 16, Loss Train Multi: 0.0374, Acc Train Multi: 0.9863, Loss Val Multi: 0.0016, Acc Val Multi: 0.9367, Loss Test Multi: 0.0022, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 17, Loss Train Multi: 0.0309, Acc Train Multi: 0.9883, Loss Val Multi: 0.0017, Acc Val Multi: 0.9317, Loss Test Multi: 0.0021, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 18, Loss Train Multi: 0.0391, Acc Train Multi: 0.9840, Loss Val Multi: 0.0016, Acc Val Multi: 0.9317, Loss Test Multi: 0.0020, Acc Test Multi: 0.9450
# Start training...
# Start validation...
# Start validation...
# Epoca 19, Loss Train Multi: 0.0439, Acc Train Multi: 0.9847, Loss Val Multi: 0.0018, Acc Val Multi: 0.9217, Loss Test Multi: 0.0022, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 20, Loss Train Multi: 0.0274, Acc Train Multi: 0.9897, Loss Val Multi: 0.0024, Acc Val Multi: 0.9250, Loss Test Multi: 0.0029, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 21, Loss Train Multi: 0.0215, Acc Train Multi: 0.9923, Loss Val Multi: 0.0016, Acc Val Multi: 0.9400, Loss Test Multi: 0.0025, Acc Test Multi: 0.9375
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 22, Loss Train Multi: 0.0147, Acc Train Multi: 0.9963, Loss Val Multi: 0.0018, Acc Val Multi: 0.9333, Loss Test Multi: 0.0025, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 23, Loss Train Multi: 0.0170, Acc Train Multi: 0.9953, Loss Val Multi: 0.0017, Acc Val Multi: 0.9383, Loss Test Multi: 0.0025, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 24, Loss Train Multi: 0.0183, Acc Train Multi: 0.9940, Loss Val Multi: 0.0023, Acc Val Multi: 0.9250, Loss Test Multi: 0.0025, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 25, Loss Train Multi: 0.0210, Acc Train Multi: 0.9943, Loss Val Multi: 0.0021, Acc Val Multi: 0.9283, Loss Test Multi: 0.0025, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 26, Loss Train Multi: 0.0158, Acc Train Multi: 0.9950, Loss Val Multi: 0.0018, Acc Val Multi: 0.9317, Loss Test Multi: 0.0024, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 27, Loss Train Multi: 0.0118, Acc Train Multi: 0.9963, Loss Val Multi: 0.0020, Acc Val Multi: 0.9333, Loss Test Multi: 0.0026, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 28, Loss Train Multi: 0.0103, Acc Train Multi: 0.9983, Loss Val Multi: 0.0023, Acc Val Multi: 0.9250, Loss Test Multi: 0.0026, Acc Test Multi: 0.9450
# Start training...
# Start validation...
# Start validation...
# Epoca 29, Loss Train Multi: 0.0122, Acc Train Multi: 0.9967, Loss Val Multi: 0.0020, Acc Val Multi: 0.9383, Loss Test Multi: 0.0026, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 30, Loss Train Multi: 0.0111, Acc Train Multi: 0.9980, Loss Val Multi: 0.0019, Acc Val Multi: 0.9333, Loss Test Multi: 0.0027, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 31, Loss Train Multi: 0.0133, Acc Train Multi: 0.9967, Loss Val Multi: 0.0024, Acc Val Multi: 0.9283, Loss Test Multi: 0.0026, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 32, Loss Train Multi: 0.0090, Acc Train Multi: 0.9977, Loss Val Multi: 0.0020, Acc Val Multi: 0.9367, Loss Test Multi: 0.0027, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 33, Loss Train Multi: 0.0080, Acc Train Multi: 0.9977, Loss Val Multi: 0.0019, Acc Val Multi: 0.9400, Loss Test Multi: 0.0028, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 34, Loss Train Multi: 0.0064, Acc Train Multi: 0.9990, Loss Val Multi: 0.0021, Acc Val Multi: 0.9367, Loss Test Multi: 0.0029, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 35, Loss Train Multi: 0.0061, Acc Train Multi: 0.9980, Loss Val Multi: 0.0022, Acc Val Multi: 0.9367, Loss Test Multi: 0.0029, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 36, Loss Train Multi: 0.0094, Acc Train Multi: 0.9970, Loss Val Multi: 0.0021, Acc Val Multi: 0.9283, Loss Test Multi: 0.0027, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 37, Loss Train Multi: 0.0088, Acc Train Multi: 0.9977, Loss Val Multi: 0.0020, Acc Val Multi: 0.9333, Loss Test Multi: 0.0027, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 38, Loss Train Multi: 0.0070, Acc Train Multi: 0.9980, Loss Val Multi: 0.0021, Acc Val Multi: 0.9417, Loss Test Multi: 0.0027, Acc Test Multi: 0.9400
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 39, Loss Train Multi: 0.0082, Acc Train Multi: 0.9967, Loss Val Multi: 0.0025, Acc Val Multi: 0.9283, Loss Test Multi: 0.0029, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 40, Loss Train Multi: 0.0044, Acc Train Multi: 0.9993, Loss Val Multi: 0.0022, Acc Val Multi: 0.9417, Loss Test Multi: 0.0030, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 41, Loss Train Multi: 0.0069, Acc Train Multi: 0.9983, Loss Val Multi: 0.0020, Acc Val Multi: 0.9383, Loss Test Multi: 0.0030, Acc Test Multi: 0.9275
# Start training...
# Start validation...
# Start validation...
# Epoca 42, Loss Train Multi: 0.0051, Acc Train Multi: 0.9987, Loss Val Multi: 0.0022, Acc Val Multi: 0.9383, Loss Test Multi: 0.0030, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 43, Loss Train Multi: 0.0050, Acc Train Multi: 0.9987, Loss Val Multi: 0.0022, Acc Val Multi: 0.9333, Loss Test Multi: 0.0029, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 44, Loss Train Multi: 0.0040, Acc Train Multi: 0.9990, Loss Val Multi: 0.0021, Acc Val Multi: 0.9350, Loss Test Multi: 0.0029, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 45, Loss Train Multi: 0.0046, Acc Train Multi: 0.9990, Loss Val Multi: 0.0021, Acc Val Multi: 0.9417, Loss Test Multi: 0.0030, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 46, Loss Train Multi: 0.0035, Acc Train Multi: 0.9997, Loss Val Multi: 0.0021, Acc Val Multi: 0.9350, Loss Test Multi: 0.0030, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 47, Loss Train Multi: 0.0065, Acc Train Multi: 0.9990, Loss Val Multi: 0.0021, Acc Val Multi: 0.9450, Loss Test Multi: 0.0031, Acc Test Multi: 0.9350
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 48, Loss Train Multi: 0.0055, Acc Train Multi: 0.9987, Loss Val Multi: 0.0023, Acc Val Multi: 0.9300, Loss Test Multi: 0.0030, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 49, Loss Train Multi: 0.0037, Acc Train Multi: 0.9990, Loss Val Multi: 0.0023, Acc Val Multi: 0.9283, Loss Test Multi: 0.0031, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 50, Loss Train Multi: 0.0056, Acc Train Multi: 0.9990, Loss Val Multi: 0.0021, Acc Val Multi: 0.9400, Loss Test Multi: 0.0031, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 51, Loss Train Multi: 0.0041, Acc Train Multi: 0.9990, Loss Val Multi: 0.0022, Acc Val Multi: 0.9400, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 52, Loss Train Multi: 0.0049, Acc Train Multi: 0.9987, Loss Val Multi: 0.0022, Acc Val Multi: 0.9433, Loss Test Multi: 0.0031, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 53, Loss Train Multi: 0.0043, Acc Train Multi: 0.9990, Loss Val Multi: 0.0024, Acc Val Multi: 0.9400, Loss Test Multi: 0.0031, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 54, Loss Train Multi: 0.0025, Acc Train Multi: 0.9993, Loss Val Multi: 0.0022, Acc Val Multi: 0.9400, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 55, Loss Train Multi: 0.0046, Acc Train Multi: 0.9980, Loss Val Multi: 0.0024, Acc Val Multi: 0.9350, Loss Test Multi: 0.0031, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 56, Loss Train Multi: 0.0037, Acc Train Multi: 0.9990, Loss Val Multi: 0.0024, Acc Val Multi: 0.9400, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 57, Loss Train Multi: 0.0025, Acc Train Multi: 0.9997, Loss Val Multi: 0.0025, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 58, Loss Train Multi: 0.0044, Acc Train Multi: 0.9990, Loss Val Multi: 0.0024, Acc Val Multi: 0.9383, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 59, Loss Train Multi: 0.0047, Acc Train Multi: 0.9990, Loss Val Multi: 0.0024, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 60, Loss Train Multi: 0.0050, Acc Train Multi: 0.9997, Loss Val Multi: 0.0021, Acc Val Multi: 0.9417, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 61, Loss Train Multi: 0.0035, Acc Train Multi: 0.9990, Loss Val Multi: 0.0022, Acc Val Multi: 0.9433, Loss Test Multi: 0.0031, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 62, Loss Train Multi: 0.0029, Acc Train Multi: 0.9993, Loss Val Multi: 0.0021, Acc Val Multi: 0.9450, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 63, Loss Train Multi: 0.0062, Acc Train Multi: 0.9983, Loss Val Multi: 0.0023, Acc Val Multi: 0.9383, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 64, Loss Train Multi: 0.0034, Acc Train Multi: 0.9990, Loss Val Multi: 0.0026, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 65, Loss Train Multi: 0.0036, Acc Train Multi: 0.9990, Loss Val Multi: 0.0022, Acc Val Multi: 0.9367, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 66, Loss Train Multi: 0.0035, Acc Train Multi: 0.9987, Loss Val Multi: 0.0023, Acc Val Multi: 0.9417, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 67, Loss Train Multi: 0.0025, Acc Train Multi: 1.0000, Loss Val Multi: 0.0024, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 68, Loss Train Multi: 0.0051, Acc Train Multi: 0.9987, Loss Val Multi: 0.0025, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 69, Loss Train Multi: 0.0057, Acc Train Multi: 0.9983, Loss Val Multi: 0.0025, Acc Val Multi: 0.9350, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 70, Loss Train Multi: 0.0019, Acc Train Multi: 1.0000, Loss Val Multi: 0.0023, Acc Val Multi: 0.9417, Loss Test Multi: 0.0031, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 71, Loss Train Multi: 0.0024, Acc Train Multi: 0.9997, Loss Val Multi: 0.0023, Acc Val Multi: 0.9400, Loss Test Multi: 0.0031, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 72, Loss Train Multi: 0.0040, Acc Train Multi: 0.9990, Loss Val Multi: 0.0022, Acc Val Multi: 0.9383, Loss Test Multi: 0.0032, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 73, Loss Train Multi: 0.0035, Acc Train Multi: 0.9990, Loss Val Multi: 0.0024, Acc Val Multi: 0.9400, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 74, Loss Train Multi: 0.0030, Acc Train Multi: 0.9993, Loss Val Multi: 0.0022, Acc Val Multi: 0.9433, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 75, Loss Train Multi: 0.0050, Acc Train Multi: 0.9983, Loss Val Multi: 0.0023, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 76, Loss Train Multi: 0.0027, Acc Train Multi: 0.9993, Loss Val Multi: 0.0022, Acc Val Multi: 0.9433, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 77, Loss Train Multi: 0.0023, Acc Train Multi: 0.9997, Loss Val Multi: 0.0022, Acc Val Multi: 0.9417, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 78, Loss Train Multi: 0.0032, Acc Train Multi: 0.9997, Loss Val Multi: 0.0023, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 79, Loss Train Multi: 0.0035, Acc Train Multi: 0.9990, Loss Val Multi: 0.0023, Acc Val Multi: 0.9417, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 80, Loss Train Multi: 0.0028, Acc Train Multi: 0.9997, Loss Val Multi: 0.0022, Acc Val Multi: 0.9433, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 81, Loss Train Multi: 0.0045, Acc Train Multi: 0.9987, Loss Val Multi: 0.0022, Acc Val Multi: 0.9417, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 82, Loss Train Multi: 0.0027, Acc Train Multi: 0.9997, Loss Val Multi: 0.0024, Acc Val Multi: 0.9417, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 83, Loss Train Multi: 0.0036, Acc Train Multi: 0.9990, Loss Val Multi: 0.0022, Acc Val Multi: 0.9417, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 84, Loss Train Multi: 0.0037, Acc Train Multi: 0.9990, Loss Val Multi: 0.0024, Acc Val Multi: 0.9367, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 85, Loss Train Multi: 0.0023, Acc Train Multi: 0.9993, Loss Val Multi: 0.0023, Acc Val Multi: 0.9367, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 86, Loss Train Multi: 0.0024, Acc Train Multi: 0.9997, Loss Val Multi: 0.0024, Acc Val Multi: 0.9367, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 87, Loss Train Multi: 0.0031, Acc Train Multi: 0.9993, Loss Val Multi: 0.0023, Acc Val Multi: 0.9400, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 88, Loss Train Multi: 0.0015, Acc Train Multi: 1.0000, Loss Val Multi: 0.0024, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 89, Loss Train Multi: 0.0034, Acc Train Multi: 0.9990, Loss Val Multi: 0.0023, Acc Val Multi: 0.9383, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 90, Loss Train Multi: 0.0021, Acc Train Multi: 0.9993, Loss Val Multi: 0.0024, Acc Val Multi: 0.9400, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 91, Loss Train Multi: 0.0013, Acc Train Multi: 1.0000, Loss Val Multi: 0.0021, Acc Val Multi: 0.9417, Loss Test Multi: 0.0033, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 92, Loss Train Multi: 0.0028, Acc Train Multi: 0.9990, Loss Val Multi: 0.0024, Acc Val Multi: 0.9367, Loss Test Multi: 0.0032, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 93, Loss Train Multi: 0.0028, Acc Train Multi: 0.9997, Loss Val Multi: 0.0024, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 94, Loss Train Multi: 0.0035, Acc Train Multi: 0.9987, Loss Val Multi: 0.0023, Acc Val Multi: 0.9350, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 95, Loss Train Multi: 0.0028, Acc Train Multi: 0.9997, Loss Val Multi: 0.0021, Acc Val Multi: 0.9417, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 96, Loss Train Multi: 0.0031, Acc Train Multi: 0.9993, Loss Val Multi: 0.0024, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 97, Loss Train Multi: 0.0014, Acc Train Multi: 1.0000, Loss Val Multi: 0.0024, Acc Val Multi: 0.9367, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 98, Loss Train Multi: 0.0017, Acc Train Multi: 1.0000, Loss Val Multi: 0.0022, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 99, Loss Train Multi: 0.0016, Acc Train Multi: 1.0000, Loss Val Multi: 0.0023, Acc Val Multi: 0.9417, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 100, Loss Train Multi: 0.0038, Acc Train Multi: 0.9990, Loss Val Multi: 0.0023, Acc Val Multi: 0.9417, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Loss plot salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/multiclass_loss_plot.png
# Accuracy plot salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/multiclass_accuracy_plot.png
# Training completato.

# %% [markdown]
# ## Training for Segmentation

# %%
def iou(pred, target, threshold=0.5):
    pred = pred > threshold
    target = target > threshold

    intersection = (pred & target).float().sum((1, 2))
    union = (pred | target).float().sum((1, 2))

    iou_score = (intersection + 1e-6) / (union + 1e-6) 
    return iou_score.mean().item()

def miou(pred, target, num_classes=2, threshold=0.5):
    pred = pred > threshold
    target = target > threshold

    iou_per_class = []
    for cls in range(num_classes):
        pred_cls = pred == cls
        target_cls = target == cls

        intersection = (pred_cls & target_cls).float().sum((1, 2))
        union = (pred_cls | target_cls).float().sum((1, 2))

        # Calcola IoU per questa classe, evita divisione per 0
        iou = (intersection + 1e-6) / (union + 1e-6)
        iou_per_class.append(iou.mean().item())

    # Calcola la media delle IoU
    return sum(iou_per_class) / num_classes


def dice_coeff(pred, target, threshold=0.5):
    pred = pred > threshold
    target = target > threshold

    intersection = (pred & target).float().sum((1, 2))
    total = pred.float().sum((1, 2)) + target.float().sum((1, 2))

    dice_score = (2.0 * intersection + 1e-6) / (total + 1e-6)
    return dice_score.mean().item()

# %%
def train_seg_model(model, dataloader, criterion, optimizer):
    model.train()

    running_loss = 0.0
    iou_score = 0.0
    dice_score = 0.0
    miou_score = 0.0  # Per mIoU

    for images, masks in dataloader:
        images = images.to(args['device'])
        masks = masks.to(args['device'])

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, masks)

        # Backward pass e ottimizzazione
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        iou_score += iou(outputs, masks) * images.size(0)
        dice_score += dice_coeff(outputs, masks) * images.size(0)
        miou_score += miou(outputs, masks) * images.size(0)  # Calcolo della mIoU

    epoch_loss = running_loss / len(dataloader.dataset)
    iou_score = iou_score / len(dataloader.dataset)
    dice_score = dice_score / len(dataloader.dataset)
    miou_score = miou_score / len(dataloader.dataset)  # Normalizzazione della mIoU
    return epoch_loss, iou_score, dice_score, miou_score


def validate_seg_model(model, dataloader, criterion):
    model.eval()

    running_loss = 0.0
    iou_score = 0.0
    dice_score = 0.0
    miou_score = 0.0  # Per mIoU

    with torch.no_grad():
        for images, masks in dataloader:
            images = images.to(args['device'])
            masks = masks.to(args['device'])

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, masks)

            running_loss += loss.item() * images.size(0)
            iou_score += iou(outputs, masks) * images.size(0)
            dice_score += dice_coeff(outputs, masks) * images.size(0)
            miou_score += miou(outputs, masks) * images.size(0)  # Calcolo della mIoU

    epoch_loss = running_loss / len(dataloader.dataset)
    iou_score = iou_score / len(dataloader.dataset)
    dice_score = dice_score / len(dataloader.dataset)
    miou_score = miou_score / len(dataloader.dataset)  # Normalizzazione della mIoU
    return epoch_loss, iou_score, dice_score, miou_score

# %%
def plot_and_save_loss(metrics, save_dir):
    # Estrai le loss
    epochs = metrics['epoch']
    train_loss = metrics['train_loss']
    val_loss = metrics['val_loss']
    test_loss = metrics['test_loss']

    # Plot delle loss
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_loss, label='Train Loss')
    plt.plot(epochs, val_loss, label='Val Loss')
    plt.plot(epochs, test_loss, label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss over Epochs')
    plt.legend()
    
    # Salva il grafico
    loss_plot_path = os.path.join(save_dir, 'loss_plot_segmentation.png')
    plt.savefig(loss_plot_path)
    plt.close()

    print(f"Plot delle loss salvato in: {loss_plot_path}")


def plot_and_save_accuracy(metrics, save_dir):
    # Estrai IoU e Dice
    epochs = metrics['epoch']
    train_iou = metrics['train_iou']
    val_iou = metrics['val_iou']
    test_iou = metrics['test_iou']
    
    train_dice = metrics['train_dice']
    val_dice = metrics['val_dice']
    test_dice = metrics['test_dice']

    # Plot di IoU
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_iou, label='Train IoU')
    plt.plot(epochs, val_iou, label='Val IoU')
    plt.plot(epochs, test_iou, label='Test IoU')
    plt.xlabel('Epochs')
    plt.ylabel('IoU')
    plt.title('IoU over Epochs')
    plt.legend()
    
    # Salva il grafico di IoU
    iou_plot_path = os.path.join(save_dir, 'iou_plot_segmentation.png')
    plt.savefig(iou_plot_path)
    plt.close()

    print(f"Plot di IoU salvato in: {iou_plot_path}")

    # Plot di Dice coefficient
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_dice, label='Train Dice')
    plt.plot(epochs, val_dice, label='Val Dice')
    plt.plot(epochs, test_dice, label='Test Dice')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Coefficient')
    plt.title('Dice Coefficient over Epochs')
    plt.legend()

    # Salva il grafico di Dice coefficient
    dice_plot_path = os.path.join(save_dir, 'dice_plot_segmentation.png')
    plt.savefig(dice_plot_path)
    plt.close()

    print(f"Plot di Dice salvato in: {dice_plot_path}")

# %%
def run_training_segmentation():
    # Usa i dataloader per training, validazione e test
    train_loader = train_segmentation_loader
    val_loader = val_segmentation_loader
    test_loader = test_segmentation_loader

    metrics = Metrics(["epoch", "lr", 
                       "train_loss", "train_iou", "train_dice", "train_miou",
                       "val_loss", "val_iou", "val_dice", "val_miou",
                       "test_loss", "test_iou", "test_dice", "test_miou"])

    print("Creating new model...")
    model = SwinClassification(num_classes_multiclass=args['num_classes'], 
                               num_classes_binary=2)

    # Carica i pesi del modello classificazione migliore (multiclasse + binaria)
    model_path = os.path.join(args['save_dir'], 'model_best_val_bin+multi.pt')
    model.load_weights(model_path)

    # Converti il modello in modalità segmentazione
    model = model.convert_to_segmentation()  # Aggiungi questa funzione al tuo modello Swin

    # Sposta il modello sulla GPU
    model = model.to(args['device'])

    # Definire la loss function e l'ottimizzatore
    criterion = nn.BCEWithLogitsLoss()  # Usare BCEWithLogitsLoss per output a singolo canale e multi-classe
    optimizer = optim.Adam(model.parameters(), lr=args['lr'])

    # Numero di epoche per il training
    num_epochs = 100

    # Variabili per tenere traccia della migliore IoU su validazione e test
    best_val_iou = 0.0
    best_test_iou = 0.0

    for epoch in range(num_epochs):
        # Fase di training
        epoch_loss, iou_score, dice_score, miou_score = train_seg_model(model, train_loader, criterion, optimizer)
        
        # Fase di validazione
        val_loss, val_iou, val_dice, val_miou = validate_seg_model(model, val_loader, criterion)
    
        # Fase di test
        test_loss, test_iou, test_dice, test_miou = validate_seg_model(model, test_loader, criterion)
    
        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Train Loss: {epoch_loss:.4f}, Train IoU: {iou_score:.4f}, Train Dice: {dice_score:.4f}, Train mIoU: {miou_score:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val IoU: {val_iou:.4f}, Val Dice: {val_dice:.4f}, Val mIoU: {val_miou:.4f}, "
              f"Test Loss: {test_loss:.4f}, Test IoU: {test_iou:.4f}, Test Dice: {test_dice:.4f}, Test mIoU: {test_miou:.4f}")
    
        # Salvataggio dei risultati
        lr = optimizer.param_groups[0]["lr"]
        metrics.add_row([
            epoch+1, 
            lr, 
            epoch_loss, 
            iou_score, 
            dice_score,
            miou_score,
            val_loss,
            val_iou,
            val_dice,
            val_miou,
            test_loss,
            test_iou,
            test_dice,
            test_miou,
        ])
        metrics.save_to_csv(os.path.join(args['save_dir'], "metrics_segmentation.csv"))

        # Salvataggio del modello corrente
        model.save_weights(os.path.join(args['save_dir'], 'model_seg_last.pt'))

        # Salva il modello se ha la migliore IoU sul validation set
        if val_iou > best_val_iou:
            print(f"Val IoU migliorata a {val_iou:.4f}, salvataggio del modello migliore (validazione).")
            best_val_iou = val_iou
            model.save_weights(os.path.join(args['save_dir'], 'model_best_val_iou.pt'))

        # Salva il modello se ha la migliore IoU sul test set
        if test_iou > best_test_iou:
            print(f"Test IoU migliorata a {test_iou:.4f}, salvataggio del modello migliore (test).")
            best_test_iou = test_iou
            model.save_weights(os.path.join(args['save_dir'], 'model_best_test_iou.pt'))

    print("Training completato.")

    # Carica le metriche dal file CSV
    metrics_data = pd.read_csv(os.path.join(args['save_dir'], "metrics_segmentation.csv"))

    # Salva i plot di Loss e Accuracy (IoU e Dice coefficient)
    plot_and_save_loss(metrics_data, args['save_dir'])
    plot_and_save_accuracy(metrics_data, args['save_dir'])

# Esegui il training per la segmentazione
run_training_segmentation()
# Out:
# Creating new model...
# Loading pre-trained: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_bin+multi.pt
# Epoch 1/100, Train Loss: 0.7893, Train IoU: 0.2729, Train Dice: 0.3380, Train mIoU: 0.4920, Val Loss: 0.7208, Val IoU: 0.5317, Val Dice: 0.5317, Val mIoU: 0.6843, Test Loss: 0.7204, Test IoU: 0.5428, Test Dice: 0.5428, Test mIoU: 0.6879
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.5317, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.5428, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 2/100, Train Loss: 0.6578, Train IoU: 0.6564, Train Dice: 0.7074, Train mIoU: 0.7614, Val Loss: 0.7050, Val IoU: 0.5678, Val Dice: 0.5917, Val mIoU: 0.7072, Test Loss: 0.7040, Test IoU: 0.5543, Test Dice: 0.5808, Test mIoU: 0.6976
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.5678, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.5543, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 3/100, Train Loss: 0.5986, Train IoU: 0.7361, Train Dice: 0.7821, Train mIoU: 0.8137, Val Loss: 0.6693, Val IoU: 0.7163, Val Dice: 0.7653, Val mIoU: 0.8047, Test Loss: 0.6652, Test IoU: 0.7390, Test Dice: 0.7861, Test mIoU: 0.8188
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.7163, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.7390, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 4/100, Train Loss: 0.5572, Train IoU: 0.7651, Train Dice: 0.8077, Train mIoU: 0.8356, Val Loss: 0.6246, Val IoU: 0.7692, Val Dice: 0.8089, Val mIoU: 0.8417, Test Loss: 0.6181, Test IoU: 0.7857, Test Dice: 0.8253, Test mIoU: 0.8534
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.7692, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.7857, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 5/100, Train Loss: 0.5257, Train IoU: 0.7881, Train Dice: 0.8278, Train mIoU: 0.8512, Val Loss: 0.5836, Val IoU: 0.7778, Val Dice: 0.8169, Val mIoU: 0.8470, Test Loss: 0.5733, Test IoU: 0.8040, Test Dice: 0.8421, Test mIoU: 0.8629
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.7778, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8040, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 6/100, Train Loss: 0.4983, Train IoU: 0.8029, Train Dice: 0.8407, Train mIoU: 0.8623, Val Loss: 0.5710, Val IoU: 0.7674, Val Dice: 0.8073, Val mIoU: 0.8348, Test Loss: 0.5601, Test IoU: 0.7816, Test Dice: 0.8214, Test mIoU: 0.8452
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 7/100, Train Loss: 0.4813, Train IoU: 0.8135, Train Dice: 0.8488, Train mIoU: 0.8705, Val Loss: 0.5342, Val IoU: 0.7834, Val Dice: 0.8227, Val mIoU: 0.8476, Test Loss: 0.5142, Test IoU: 0.8149, Test Dice: 0.8514, Test mIoU: 0.8700
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.7834, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8149, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 8/100, Train Loss: 0.4652, Train IoU: 0.8309, Train Dice: 0.8647, Train mIoU: 0.8821, Val Loss: 0.4921, Val IoU: 0.8223, Val Dice: 0.8544, Val mIoU: 0.8739, Test Loss: 0.4804, Test IoU: 0.8275, Test Dice: 0.8599, Test mIoU: 0.8802
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8223, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8275, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 9/100, Train Loss: 0.4556, Train IoU: 0.8360, Train Dice: 0.8680, Train mIoU: 0.8858, Val Loss: 0.4982, Val IoU: 0.8108, Val Dice: 0.8455, Val mIoU: 0.8655, Test Loss: 0.4842, Test IoU: 0.8277, Test Dice: 0.8600, Test mIoU: 0.8776
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.8277, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 10/100, Train Loss: 0.4453, Train IoU: 0.8441, Train Dice: 0.8759, Train mIoU: 0.8913, Val Loss: 0.4623, Val IoU: 0.8348, Val Dice: 0.8646, Val mIoU: 0.8840, Test Loss: 0.4422, Test IoU: 0.8532, Test Dice: 0.8832, Test mIoU: 0.8958
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8348, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8532, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 11/100, Train Loss: 0.4389, Train IoU: 0.8478, Train Dice: 0.8784, Train mIoU: 0.8931, Val Loss: 0.4535, Val IoU: 0.8356, Val Dice: 0.8653, Val mIoU: 0.8857, Test Loss: 0.4345, Test IoU: 0.8601, Test Dice: 0.8901, Test mIoU: 0.9032
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8356, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8601, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 12/100, Train Loss: 0.4312, Train IoU: 0.8539, Train Dice: 0.8839, Train mIoU: 0.8982, Val Loss: 0.4553, Val IoU: 0.8294, Val Dice: 0.8594, Val mIoU: 0.8806, Test Loss: 0.4604, Test IoU: 0.8386, Test Dice: 0.8698, Test mIoU: 0.8840
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 13/100, Train Loss: 0.4226, Train IoU: 0.8613, Train Dice: 0.8905, Train mIoU: 0.9027, Val Loss: 0.4363, Val IoU: 0.8507, Val Dice: 0.8789, Val mIoU: 0.8946, Test Loss: 0.4233, Test IoU: 0.8636, Test Dice: 0.8916, Test mIoU: 0.9057
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8507, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8636, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 14/100, Train Loss: 0.4146, Train IoU: 0.8667, Train Dice: 0.8949, Train mIoU: 0.9075, Val Loss: 0.4318, Val IoU: 0.8320, Val Dice: 0.8622, Val mIoU: 0.8834, Test Loss: 0.4165, Test IoU: 0.8585, Test Dice: 0.8888, Test mIoU: 0.9013
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 15/100, Train Loss: 0.4110, Train IoU: 0.8723, Train Dice: 0.8994, Train mIoU: 0.9110, Val Loss: 0.4496, Val IoU: 0.8425, Val Dice: 0.8709, Val mIoU: 0.8883, Test Loss: 0.4399, Test IoU: 0.8507, Test Dice: 0.8785, Test mIoU: 0.8938
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 16/100, Train Loss: 0.4049, Train IoU: 0.8775, Train Dice: 0.9044, Train mIoU: 0.9144, Val Loss: 0.4189, Val IoU: 0.8455, Val Dice: 0.8741, Val mIoU: 0.8924, Test Loss: 0.4071, Test IoU: 0.8707, Test Dice: 0.8971, Test mIoU: 0.9094
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.8707, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 17/100, Train Loss: 0.4010, Train IoU: 0.8775, Train Dice: 0.9039, Train mIoU: 0.9151, Val Loss: 0.4404, Val IoU: 0.8494, Val Dice: 0.8772, Val mIoU: 0.8924, Test Loss: 0.4203, Test IoU: 0.8637, Test Dice: 0.8895, Test mIoU: 0.9055
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 18/100, Train Loss: 0.3970, Train IoU: 0.8787, Train Dice: 0.9047, Train mIoU: 0.9160, Val Loss: 0.4168, Val IoU: 0.8544, Val Dice: 0.8821, Val mIoU: 0.8970, Test Loss: 0.3978, Test IoU: 0.8729, Test Dice: 0.8993, Test mIoU: 0.9125
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8544, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8729, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 19/100, Train Loss: 0.3919, Train IoU: 0.8895, Train Dice: 0.9145, Train mIoU: 0.9229, Val Loss: 0.4226, Val IoU: 0.8560, Val Dice: 0.8819, Val mIoU: 0.8995, Test Loss: 0.4011, Test IoU: 0.8788, Test Dice: 0.9043, Test mIoU: 0.9162
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8560, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8788, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 20/100, Train Loss: 0.3885, Train IoU: 0.8880, Train Dice: 0.9128, Train mIoU: 0.9221, Val Loss: 0.4239, Val IoU: 0.8559, Val Dice: 0.8812, Val mIoU: 0.8981, Test Loss: 0.3996, Test IoU: 0.8759, Test Dice: 0.9023, Test mIoU: 0.9140
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 21/100, Train Loss: 0.3864, Train IoU: 0.8914, Train Dice: 0.9162, Train mIoU: 0.9240, Val Loss: 0.4022, Val IoU: 0.8672, Val Dice: 0.8920, Val mIoU: 0.9069, Test Loss: 0.3944, Test IoU: 0.8799, Test Dice: 0.9055, Test mIoU: 0.9170
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8672, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8799, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 22/100, Train Loss: 0.3824, Train IoU: 0.8911, Train Dice: 0.9152, Train mIoU: 0.9248, Val Loss: 0.4194, Val IoU: 0.8577, Val Dice: 0.8835, Val mIoU: 0.9002, Test Loss: 0.3965, Test IoU: 0.8770, Test Dice: 0.9020, Test mIoU: 0.9165
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 23/100, Train Loss: 0.3814, Train IoU: 0.8915, Train Dice: 0.9153, Train mIoU: 0.9252, Val Loss: 0.4042, Val IoU: 0.8672, Val Dice: 0.8940, Val mIoU: 0.9052, Test Loss: 0.3946, Test IoU: 0.8747, Test Dice: 0.8999, Test mIoU: 0.9127
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8672, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 24/100, Train Loss: 0.3782, Train IoU: 0.8911, Train Dice: 0.9152, Train mIoU: 0.9240, Val Loss: 0.3945, Val IoU: 0.8693, Val Dice: 0.8944, Val mIoU: 0.9085, Test Loss: 0.3867, Test IoU: 0.8883, Test Dice: 0.9125, Test mIoU: 0.9215
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8693, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.8883, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 25/100, Train Loss: 0.3755, Train IoU: 0.8933, Train Dice: 0.9176, Train mIoU: 0.9258, Val Loss: 0.3987, Val IoU: 0.8705, Val Dice: 0.8961, Val mIoU: 0.9083, Test Loss: 0.3904, Test IoU: 0.8826, Test Dice: 0.9079, Test mIoU: 0.9166
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8705, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 26/100, Train Loss: 0.3727, Train IoU: 0.8940, Train Dice: 0.9185, Train mIoU: 0.9268, Val Loss: 0.4029, Val IoU: 0.8613, Val Dice: 0.8854, Val mIoU: 0.9026, Test Loss: 0.3764, Test IoU: 0.8865, Test Dice: 0.9102, Test mIoU: 0.9217
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 27/100, Train Loss: 0.3693, Train IoU: 0.9009, Train Dice: 0.9240, Train mIoU: 0.9315, Val Loss: 0.3982, Val IoU: 0.8699, Val Dice: 0.8943, Val mIoU: 0.9087, Test Loss: 0.3874, Test IoU: 0.8757, Test Dice: 0.8999, Test mIoU: 0.9139
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 28/100, Train Loss: 0.3667, Train IoU: 0.9008, Train Dice: 0.9241, Train mIoU: 0.9314, Val Loss: 0.4120, Val IoU: 0.8559, Val Dice: 0.8822, Val mIoU: 0.8986, Test Loss: 0.3962, Test IoU: 0.8707, Test Dice: 0.8963, Test mIoU: 0.9092
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 29/100, Train Loss: 0.3634, Train IoU: 0.9020, Train Dice: 0.9248, Train mIoU: 0.9319, Val Loss: 0.3889, Val IoU: 0.8625, Val Dice: 0.8889, Val mIoU: 0.9029, Test Loss: 0.3678, Test IoU: 0.8859, Test Dice: 0.9102, Test mIoU: 0.9215
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 30/100, Train Loss: 0.3620, Train IoU: 0.8990, Train Dice: 0.9223, Train mIoU: 0.9305, Val Loss: 0.3994, Val IoU: 0.8630, Val Dice: 0.8883, Val mIoU: 0.9040, Test Loss: 0.3922, Test IoU: 0.8792, Test Dice: 0.9027, Test mIoU: 0.9151
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 31/100, Train Loss: 0.3590, Train IoU: 0.9020, Train Dice: 0.9247, Train mIoU: 0.9325, Val Loss: 0.3779, Val IoU: 0.8750, Val Dice: 0.9003, Val mIoU: 0.9120, Test Loss: 0.3786, Test IoU: 0.8781, Test Dice: 0.9036, Test mIoU: 0.9149
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8750, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 32/100, Train Loss: 0.3571, Train IoU: 0.9049, Train Dice: 0.9273, Train mIoU: 0.9350, Val Loss: 0.3889, Val IoU: 0.8629, Val Dice: 0.8885, Val mIoU: 0.9044, Test Loss: 0.3745, Test IoU: 0.8886, Test Dice: 0.9121, Test mIoU: 0.9221
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.8886, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 33/100, Train Loss: 0.3546, Train IoU: 0.9036, Train Dice: 0.9260, Train mIoU: 0.9336, Val Loss: 0.3813, Val IoU: 0.8747, Val Dice: 0.8988, Val mIoU: 0.9111, Test Loss: 0.3652, Test IoU: 0.8932, Test Dice: 0.9166, Test mIoU: 0.9245
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.8932, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 34/100, Train Loss: 0.3521, Train IoU: 0.9062, Train Dice: 0.9285, Train mIoU: 0.9349, Val Loss: 0.3919, Val IoU: 0.8672, Val Dice: 0.8928, Val mIoU: 0.9033, Test Loss: 0.3655, Test IoU: 0.8898, Test Dice: 0.9143, Test mIoU: 0.9220
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 35/100, Train Loss: 0.3494, Train IoU: 0.9101, Train Dice: 0.9319, Train mIoU: 0.9383, Val Loss: 0.3770, Val IoU: 0.8750, Val Dice: 0.8998, Val mIoU: 0.9134, Test Loss: 0.3658, Test IoU: 0.8916, Test Dice: 0.9155, Test mIoU: 0.9229
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8750, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 36/100, Train Loss: 0.3499, Train IoU: 0.9054, Train Dice: 0.9284, Train mIoU: 0.9347, Val Loss: 0.3783, Val IoU: 0.8647, Val Dice: 0.8908, Val mIoU: 0.9055, Test Loss: 0.3598, Test IoU: 0.8938, Test Dice: 0.9183, Test mIoU: 0.9258
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.8938, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 37/100, Train Loss: 0.3474, Train IoU: 0.9025, Train Dice: 0.9257, Train mIoU: 0.9337, Val Loss: 0.3922, Val IoU: 0.8601, Val Dice: 0.8859, Val mIoU: 0.9023, Test Loss: 0.3667, Test IoU: 0.8877, Test Dice: 0.9131, Test mIoU: 0.9210
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 38/100, Train Loss: 0.3435, Train IoU: 0.9121, Train Dice: 0.9338, Train mIoU: 0.9393, Val Loss: 0.3709, Val IoU: 0.8767, Val Dice: 0.9000, Val mIoU: 0.9137, Test Loss: 0.3523, Test IoU: 0.9016, Test Dice: 0.9246, Test mIoU: 0.9307
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8767, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Test IoU migliorata a 0.9016, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 39/100, Train Loss: 0.3410, Train IoU: 0.9070, Train Dice: 0.9288, Train mIoU: 0.9364, Val Loss: 0.3675, Val IoU: 0.8808, Val Dice: 0.9045, Val mIoU: 0.9160, Test Loss: 0.3556, Test IoU: 0.8903, Test Dice: 0.9123, Test mIoU: 0.9257
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8808, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 40/100, Train Loss: 0.3389, Train IoU: 0.9121, Train Dice: 0.9333, Train mIoU: 0.9399, Val Loss: 0.3714, Val IoU: 0.8802, Val Dice: 0.9036, Val mIoU: 0.9159, Test Loss: 0.3634, Test IoU: 0.8837, Test Dice: 0.9070, Test mIoU: 0.9183
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 41/100, Train Loss: 0.3351, Train IoU: 0.9121, Train Dice: 0.9336, Train mIoU: 0.9388, Val Loss: 0.3713, Val IoU: 0.8708, Val Dice: 0.8945, Val mIoU: 0.9092, Test Loss: 0.3540, Test IoU: 0.8891, Test Dice: 0.9124, Test mIoU: 0.9232
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 42/100, Train Loss: 0.3355, Train IoU: 0.9104, Train Dice: 0.9324, Train mIoU: 0.9384, Val Loss: 0.3620, Val IoU: 0.8765, Val Dice: 0.8997, Val mIoU: 0.9137, Test Loss: 0.3580, Test IoU: 0.8856, Test Dice: 0.9086, Test mIoU: 0.9209
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 43/100, Train Loss: 0.3342, Train IoU: 0.9101, Train Dice: 0.9315, Train mIoU: 0.9390, Val Loss: 0.3580, Val IoU: 0.8622, Val Dice: 0.8868, Val mIoU: 0.9048, Test Loss: 0.3527, Test IoU: 0.8806, Test Dice: 0.9042, Test mIoU: 0.9170
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 44/100, Train Loss: 0.3311, Train IoU: 0.9115, Train Dice: 0.9335, Train mIoU: 0.9389, Val Loss: 0.3632, Val IoU: 0.8778, Val Dice: 0.9002, Val mIoU: 0.9152, Test Loss: 0.3512, Test IoU: 0.8852, Test Dice: 0.9083, Test mIoU: 0.9206
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 45/100, Train Loss: 0.3276, Train IoU: 0.9144, Train Dice: 0.9357, Train mIoU: 0.9411, Val Loss: 0.3590, Val IoU: 0.8756, Val Dice: 0.8993, Val mIoU: 0.9133, Test Loss: 0.3455, Test IoU: 0.8859, Test Dice: 0.9096, Test mIoU: 0.9230
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 46/100, Train Loss: 0.3270, Train IoU: 0.9136, Train Dice: 0.9349, Train mIoU: 0.9407, Val Loss: 0.3594, Val IoU: 0.8715, Val Dice: 0.8956, Val mIoU: 0.9089, Test Loss: 0.3475, Test IoU: 0.8781, Test Dice: 0.9008, Test mIoU: 0.9176
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 47/100, Train Loss: 0.3266, Train IoU: 0.9134, Train Dice: 0.9352, Train mIoU: 0.9405, Val Loss: 0.3618, Val IoU: 0.8788, Val Dice: 0.9026, Val mIoU: 0.9134, Test Loss: 0.3587, Test IoU: 0.8820, Test Dice: 0.9052, Test mIoU: 0.9187
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 48/100, Train Loss: 0.3220, Train IoU: 0.9168, Train Dice: 0.9373, Train mIoU: 0.9430, Val Loss: 0.3631, Val IoU: 0.8727, Val Dice: 0.8956, Val mIoU: 0.9102, Test Loss: 0.3446, Test IoU: 0.8893, Test Dice: 0.9107, Test mIoU: 0.9243
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 49/100, Train Loss: 0.3204, Train IoU: 0.9141, Train Dice: 0.9357, Train mIoU: 0.9414, Val Loss: 0.3553, Val IoU: 0.8771, Val Dice: 0.8998, Val mIoU: 0.9126, Test Loss: 0.3438, Test IoU: 0.8841, Test Dice: 0.9062, Test mIoU: 0.9194
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 50/100, Train Loss: 0.3189, Train IoU: 0.9173, Train Dice: 0.9380, Train mIoU: 0.9428, Val Loss: 0.3593, Val IoU: 0.8747, Val Dice: 0.8974, Val mIoU: 0.9121, Test Loss: 0.3378, Test IoU: 0.8916, Test Dice: 0.9147, Test mIoU: 0.9254
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 51/100, Train Loss: 0.3168, Train IoU: 0.9177, Train Dice: 0.9382, Train mIoU: 0.9441, Val Loss: 0.3615, Val IoU: 0.8732, Val Dice: 0.8963, Val mIoU: 0.9115, Test Loss: 0.3399, Test IoU: 0.8930, Test Dice: 0.9160, Test mIoU: 0.9243
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 52/100, Train Loss: 0.3157, Train IoU: 0.9184, Train Dice: 0.9388, Train mIoU: 0.9445, Val Loss: 0.3492, Val IoU: 0.8794, Val Dice: 0.9018, Val mIoU: 0.9151, Test Loss: 0.3321, Test IoU: 0.8941, Test Dice: 0.9170, Test mIoU: 0.9262
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 53/100, Train Loss: 0.3125, Train IoU: 0.9210, Train Dice: 0.9408, Train mIoU: 0.9461, Val Loss: 0.3395, Val IoU: 0.8848, Val Dice: 0.9073, Val mIoU: 0.9201, Test Loss: 0.3430, Test IoU: 0.8813, Test Dice: 0.9045, Test mIoU: 0.9180
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8848, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 54/100, Train Loss: 0.3116, Train IoU: 0.9167, Train Dice: 0.9373, Train mIoU: 0.9431, Val Loss: 0.3676, Val IoU: 0.8707, Val Dice: 0.8953, Val mIoU: 0.9068, Test Loss: 0.3254, Test IoU: 0.8974, Test Dice: 0.9206, Test mIoU: 0.9299
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 55/100, Train Loss: 0.3101, Train IoU: 0.9194, Train Dice: 0.9394, Train mIoU: 0.9451, Val Loss: 0.3391, Val IoU: 0.8798, Val Dice: 0.9023, Val mIoU: 0.9162, Test Loss: 0.3238, Test IoU: 0.8912, Test Dice: 0.9145, Test mIoU: 0.9248
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 56/100, Train Loss: 0.3081, Train IoU: 0.9196, Train Dice: 0.9396, Train mIoU: 0.9447, Val Loss: 0.3510, Val IoU: 0.8756, Val Dice: 0.8980, Val mIoU: 0.9112, Test Loss: 0.3196, Test IoU: 0.9090, Test Dice: 0.9315, Test mIoU: 0.9358
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.9090, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 57/100, Train Loss: 0.3066, Train IoU: 0.9226, Train Dice: 0.9423, Train mIoU: 0.9471, Val Loss: 0.3486, Val IoU: 0.8750, Val Dice: 0.8986, Val mIoU: 0.9109, Test Loss: 0.3365, Test IoU: 0.8897, Test Dice: 0.9119, Test mIoU: 0.9235
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 58/100, Train Loss: 0.3056, Train IoU: 0.9222, Train Dice: 0.9419, Train mIoU: 0.9472, Val Loss: 0.3357, Val IoU: 0.8783, Val Dice: 0.9010, Val mIoU: 0.9149, Test Loss: 0.3224, Test IoU: 0.8916, Test Dice: 0.9147, Test mIoU: 0.9245
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 59/100, Train Loss: 0.3029, Train IoU: 0.9227, Train Dice: 0.9422, Train mIoU: 0.9467, Val Loss: 0.3470, Val IoU: 0.8661, Val Dice: 0.8892, Val mIoU: 0.9074, Test Loss: 0.3368, Test IoU: 0.8972, Test Dice: 0.9210, Test mIoU: 0.9254
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 60/100, Train Loss: 0.3012, Train IoU: 0.9203, Train Dice: 0.9401, Train mIoU: 0.9464, Val Loss: 0.3310, Val IoU: 0.8805, Val Dice: 0.9014, Val mIoU: 0.9167, Test Loss: 0.3141, Test IoU: 0.8943, Test Dice: 0.9160, Test mIoU: 0.9281
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 61/100, Train Loss: 0.2994, Train IoU: 0.9224, Train Dice: 0.9419, Train mIoU: 0.9469, Val Loss: 0.3357, Val IoU: 0.8735, Val Dice: 0.8961, Val mIoU: 0.9105, Test Loss: 0.3136, Test IoU: 0.9096, Test Dice: 0.9327, Test mIoU: 0.9360
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.9096, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 62/100, Train Loss: 0.2972, Train IoU: 0.9254, Train Dice: 0.9445, Train mIoU: 0.9488, Val Loss: 0.3365, Val IoU: 0.8728, Val Dice: 0.8947, Val mIoU: 0.9114, Test Loss: 0.3091, Test IoU: 0.8963, Test Dice: 0.9201, Test mIoU: 0.9280
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 63/100, Train Loss: 0.2954, Train IoU: 0.9241, Train Dice: 0.9432, Train mIoU: 0.9485, Val Loss: 0.3316, Val IoU: 0.8797, Val Dice: 0.9025, Val mIoU: 0.9151, Test Loss: 0.3187, Test IoU: 0.8919, Test Dice: 0.9144, Test mIoU: 0.9258
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 64/100, Train Loss: 0.2943, Train IoU: 0.9257, Train Dice: 0.9450, Train mIoU: 0.9498, Val Loss: 0.3240, Val IoU: 0.8788, Val Dice: 0.9016, Val mIoU: 0.9169, Test Loss: 0.3258, Test IoU: 0.8882, Test Dice: 0.9125, Test mIoU: 0.9202
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 65/100, Train Loss: 0.2918, Train IoU: 0.9257, Train Dice: 0.9447, Train mIoU: 0.9496, Val Loss: 0.3261, Val IoU: 0.8839, Val Dice: 0.9057, Val mIoU: 0.9194, Test Loss: 0.3135, Test IoU: 0.9011, Test Dice: 0.9231, Test mIoU: 0.9301
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 66/100, Train Loss: 0.2905, Train IoU: 0.9240, Train Dice: 0.9429, Train mIoU: 0.9486, Val Loss: 0.3274, Val IoU: 0.8782, Val Dice: 0.9009, Val mIoU: 0.9157, Test Loss: 0.3003, Test IoU: 0.9074, Test Dice: 0.9299, Test mIoU: 0.9352
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 67/100, Train Loss: 0.2907, Train IoU: 0.9238, Train Dice: 0.9429, Train mIoU: 0.9482, Val Loss: 0.3234, Val IoU: 0.8760, Val Dice: 0.8981, Val mIoU: 0.9146, Test Loss: 0.2996, Test IoU: 0.9104, Test Dice: 0.9309, Test mIoU: 0.9386
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.9104, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 68/100, Train Loss: 0.2869, Train IoU: 0.9277, Train Dice: 0.9462, Train mIoU: 0.9513, Val Loss: 0.3196, Val IoU: 0.8775, Val Dice: 0.9001, Val mIoU: 0.9150, Test Loss: 0.3052, Test IoU: 0.8853, Test Dice: 0.9090, Test mIoU: 0.9209
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 69/100, Train Loss: 0.2856, Train IoU: 0.9247, Train Dice: 0.9436, Train mIoU: 0.9488, Val Loss: 0.3240, Val IoU: 0.8858, Val Dice: 0.9078, Val mIoU: 0.9181, Test Loss: 0.2974, Test IoU: 0.9065, Test Dice: 0.9274, Test mIoU: 0.9345
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8858, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 70/100, Train Loss: 0.2841, Train IoU: 0.9264, Train Dice: 0.9456, Train mIoU: 0.9499, Val Loss: 0.3263, Val IoU: 0.8704, Val Dice: 0.8936, Val mIoU: 0.9099, Test Loss: 0.3077, Test IoU: 0.8920, Test Dice: 0.9147, Test mIoU: 0.9249
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 71/100, Train Loss: 0.2827, Train IoU: 0.9259, Train Dice: 0.9444, Train mIoU: 0.9496, Val Loss: 0.3248, Val IoU: 0.8785, Val Dice: 0.8998, Val mIoU: 0.9161, Test Loss: 0.2991, Test IoU: 0.8970, Test Dice: 0.9184, Test mIoU: 0.9288
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 72/100, Train Loss: 0.2821, Train IoU: 0.9220, Train Dice: 0.9417, Train mIoU: 0.9477, Val Loss: 0.3315, Val IoU: 0.8754, Val Dice: 0.8985, Val mIoU: 0.9117, Test Loss: 0.2935, Test IoU: 0.9035, Test Dice: 0.9248, Test mIoU: 0.9348
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 73/100, Train Loss: 0.2786, Train IoU: 0.9269, Train Dice: 0.9458, Train mIoU: 0.9501, Val Loss: 0.3182, Val IoU: 0.8818, Val Dice: 0.9052, Val mIoU: 0.9164, Test Loss: 0.2972, Test IoU: 0.8989, Test Dice: 0.9209, Test mIoU: 0.9302
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 74/100, Train Loss: 0.2784, Train IoU: 0.9263, Train Dice: 0.9453, Train mIoU: 0.9503, Val Loss: 0.3318, Val IoU: 0.8765, Val Dice: 0.8996, Val mIoU: 0.9119, Test Loss: 0.2967, Test IoU: 0.9026, Test Dice: 0.9229, Test mIoU: 0.9326
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 75/100, Train Loss: 0.2754, Train IoU: 0.9275, Train Dice: 0.9460, Train mIoU: 0.9509, Val Loss: 0.3235, Val IoU: 0.8730, Val Dice: 0.8948, Val mIoU: 0.9109, Test Loss: 0.3075, Test IoU: 0.8906, Test Dice: 0.9121, Test mIoU: 0.9243
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 76/100, Train Loss: 0.2750, Train IoU: 0.9273, Train Dice: 0.9462, Train mIoU: 0.9510, Val Loss: 0.3055, Val IoU: 0.8938, Val Dice: 0.9145, Val mIoU: 0.9264, Test Loss: 0.2916, Test IoU: 0.9053, Test Dice: 0.9263, Test mIoU: 0.9336
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Val IoU migliorata a 0.8938, salvataggio del modello migliore (validazione).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Epoch 77/100, Train Loss: 0.2730, Train IoU: 0.9284, Train Dice: 0.9471, Train mIoU: 0.9513, Val Loss: 0.3165, Val IoU: 0.8762, Val Dice: 0.8971, Val mIoU: 0.9150, Test Loss: 0.3244, Test IoU: 0.8887, Test Dice: 0.9120, Test mIoU: 0.9190
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 78/100, Train Loss: 0.2713, Train IoU: 0.9291, Train Dice: 0.9477, Train mIoU: 0.9513, Val Loss: 0.3088, Val IoU: 0.8758, Val Dice: 0.8994, Val mIoU: 0.9124, Test Loss: 0.2969, Test IoU: 0.8953, Test Dice: 0.9172, Test mIoU: 0.9275
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 79/100, Train Loss: 0.2707, Train IoU: 0.9259, Train Dice: 0.9449, Train mIoU: 0.9500, Val Loss: 0.3248, Val IoU: 0.8750, Val Dice: 0.8991, Val mIoU: 0.9098, Test Loss: 0.3103, Test IoU: 0.8947, Test Dice: 0.9164, Test mIoU: 0.9267
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 80/100, Train Loss: 0.2693, Train IoU: 0.9280, Train Dice: 0.9464, Train mIoU: 0.9511, Val Loss: 0.3051, Val IoU: 0.8796, Val Dice: 0.9002, Val mIoU: 0.9177, Test Loss: 0.3059, Test IoU: 0.8932, Test Dice: 0.9155, Test mIoU: 0.9255
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 81/100, Train Loss: 0.2664, Train IoU: 0.9302, Train Dice: 0.9487, Train mIoU: 0.9524, Val Loss: 0.3074, Val IoU: 0.8769, Val Dice: 0.8998, Val mIoU: 0.9138, Test Loss: 0.2873, Test IoU: 0.8960, Test Dice: 0.9177, Test mIoU: 0.9283
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 82/100, Train Loss: 0.2668, Train IoU: 0.9266, Train Dice: 0.9454, Train mIoU: 0.9499, Val Loss: 0.3169, Val IoU: 0.8732, Val Dice: 0.8950, Val mIoU: 0.9106, Test Loss: 0.2804, Test IoU: 0.9139, Test Dice: 0.9340, Test mIoU: 0.9382
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Test IoU migliorata a 0.9139, salvataggio del modello migliore (test).
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Epoch 83/100, Train Loss: 0.2653, Train IoU: 0.9259, Train Dice: 0.9447, Train mIoU: 0.9503, Val Loss: 0.3137, Val IoU: 0.8790, Val Dice: 0.9015, Val mIoU: 0.9144, Test Loss: 0.2895, Test IoU: 0.8963, Test Dice: 0.9187, Test mIoU: 0.9266
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 84/100, Train Loss: 0.2628, Train IoU: 0.9304, Train Dice: 0.9486, Train mIoU: 0.9530, Val Loss: 0.2994, Val IoU: 0.8881, Val Dice: 0.9089, Val mIoU: 0.9223, Test Loss: 0.2729, Test IoU: 0.9082, Test Dice: 0.9279, Test mIoU: 0.9353
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 85/100, Train Loss: 0.2612, Train IoU: 0.9311, Train Dice: 0.9490, Train mIoU: 0.9533, Val Loss: 0.3095, Val IoU: 0.8800, Val Dice: 0.9035, Val mIoU: 0.9157, Test Loss: 0.2928, Test IoU: 0.8907, Test Dice: 0.9121, Test mIoU: 0.9257
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 86/100, Train Loss: 0.2596, Train IoU: 0.9319, Train Dice: 0.9497, Train mIoU: 0.9542, Val Loss: 0.2959, Val IoU: 0.8739, Val Dice: 0.8959, Val mIoU: 0.9128, Test Loss: 0.2774, Test IoU: 0.8966, Test Dice: 0.9188, Test mIoU: 0.9278
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 87/100, Train Loss: 0.2579, Train IoU: 0.9295, Train Dice: 0.9477, Train mIoU: 0.9524, Val Loss: 0.2942, Val IoU: 0.8912, Val Dice: 0.9125, Val mIoU: 0.9234, Test Loss: 0.2798, Test IoU: 0.9076, Test Dice: 0.9296, Test mIoU: 0.9340
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 88/100, Train Loss: 0.2565, Train IoU: 0.9304, Train Dice: 0.9484, Train mIoU: 0.9524, Val Loss: 0.3040, Val IoU: 0.8739, Val Dice: 0.8966, Val mIoU: 0.9110, Test Loss: 0.2775, Test IoU: 0.9047, Test Dice: 0.9270, Test mIoU: 0.9334
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 89/100, Train Loss: 0.2558, Train IoU: 0.9305, Train Dice: 0.9484, Train mIoU: 0.9530, Val Loss: 0.2921, Val IoU: 0.8922, Val Dice: 0.9125, Val mIoU: 0.9241, Test Loss: 0.2682, Test IoU: 0.9077, Test Dice: 0.9275, Test mIoU: 0.9371
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 90/100, Train Loss: 0.2542, Train IoU: 0.9315, Train Dice: 0.9494, Train mIoU: 0.9538, Val Loss: 0.2980, Val IoU: 0.8771, Val Dice: 0.8995, Val mIoU: 0.9148, Test Loss: 0.2762, Test IoU: 0.8999, Test Dice: 0.9206, Test mIoU: 0.9303
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 91/100, Train Loss: 0.2532, Train IoU: 0.9290, Train Dice: 0.9471, Train mIoU: 0.9526, Val Loss: 0.2908, Val IoU: 0.8874, Val Dice: 0.9090, Val mIoU: 0.9212, Test Loss: 0.2697, Test IoU: 0.9065, Test Dice: 0.9285, Test mIoU: 0.9352
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 92/100, Train Loss: 0.2523, Train IoU: 0.9320, Train Dice: 0.9502, Train mIoU: 0.9532, Val Loss: 0.2935, Val IoU: 0.8760, Val Dice: 0.8998, Val mIoU: 0.9134, Test Loss: 0.3024, Test IoU: 0.8736, Test Dice: 0.8983, Test mIoU: 0.9107
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 93/100, Train Loss: 0.2510, Train IoU: 0.9256, Train Dice: 0.9447, Train mIoU: 0.9502, Val Loss: 0.3020, Val IoU: 0.8844, Val Dice: 0.9061, Val mIoU: 0.9178, Test Loss: 0.2919, Test IoU: 0.8976, Test Dice: 0.9201, Test mIoU: 0.9271
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 94/100, Train Loss: 0.2490, Train IoU: 0.9284, Train Dice: 0.9464, Train mIoU: 0.9515, Val Loss: 0.2966, Val IoU: 0.8792, Val Dice: 0.9005, Val mIoU: 0.9165, Test Loss: 0.2763, Test IoU: 0.8926, Test Dice: 0.9143, Test mIoU: 0.9252
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 95/100, Train Loss: 0.2486, Train IoU: 0.9301, Train Dice: 0.9483, Train mIoU: 0.9527, Val Loss: 0.2865, Val IoU: 0.8846, Val Dice: 0.9052, Val mIoU: 0.9205, Test Loss: 0.2738, Test IoU: 0.8909, Test Dice: 0.9134, Test mIoU: 0.9245
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 96/100, Train Loss: 0.2470, Train IoU: 0.9289, Train Dice: 0.9473, Train mIoU: 0.9519, Val Loss: 0.2863, Val IoU: 0.8896, Val Dice: 0.9097, Val mIoU: 0.9220, Test Loss: 0.2656, Test IoU: 0.9030, Test Dice: 0.9227, Test mIoU: 0.9330
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 97/100, Train Loss: 0.2476, Train IoU: 0.9281, Train Dice: 0.9460, Train mIoU: 0.9516, Val Loss: 0.2875, Val IoU: 0.8685, Val Dice: 0.8910, Val mIoU: 0.9093, Test Loss: 0.2627, Test IoU: 0.8992, Test Dice: 0.9194, Test mIoU: 0.9306
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 98/100, Train Loss: 0.2446, Train IoU: 0.9291, Train Dice: 0.9474, Train mIoU: 0.9525, Val Loss: 0.2806, Val IoU: 0.8824, Val Dice: 0.9051, Val mIoU: 0.9173, Test Loss: 0.2556, Test IoU: 0.9089, Test Dice: 0.9294, Test mIoU: 0.9359
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 99/100, Train Loss: 0.2430, Train IoU: 0.9288, Train Dice: 0.9468, Train mIoU: 0.9522, Val Loss: 0.3037, Val IoU: 0.8817, Val Dice: 0.9034, Val mIoU: 0.9155, Test Loss: 0.2857, Test IoU: 0.9001, Test Dice: 0.9208, Test mIoU: 0.9288
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Epoch 100/100, Train Loss: 0.2442, Train IoU: 0.9271, Train Dice: 0.9457, Train mIoU: 0.9507, Val Loss: 0.2944, Val IoU: 0.8710, Val Dice: 0.8950, Val mIoU: 0.9091, Test Loss: 0.2598, Test IoU: 0.8914, Test Dice: 0.9156, Test mIoU: 0.9261
# Saving model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_seg_last.pt
# Training completato.
# Plot delle loss salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/loss_plot_segmentation.png
# Plot di IoU salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/iou_plot_segmentation.png
# Plot di Dice salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/dice_plot_segmentation.png

# %% [markdown]
# ### Visualize some results

# %%
import cv2
import numpy as np
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import random
import torch
import os

def test_seg():
    seg_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # Selezione casuale dell'immagine direttamente dalla directory di test (senza sottocartelle)
    root_dir = args['test_dir_seg']  # Questa è la directory di test senza sottocartelle
    images = os.listdir(root_dir)
    valid_extensions = ('.jpg', '.jpeg', '.png')  # Definisci le estensioni valide
    images = [img for img in images if img.endswith(valid_extensions)]  # Filtra le immagini valide

    if len(images) == 0:
        raise ValueError(f"Nessuna immagine trovata nella directory: {root_dir}")

    idx = random.randint(0, len(images) - 1)
    print("Opening:", images[idx])
    img = Image.open(os.path.join(root_dir, images[idx]))
    img_tensor = seg_transform(img)
    img_tensor = img_tensor.unsqueeze(0)

    # Funzione per eseguire il modello e ottenere l'output della segmentazione
    def run_model(model_path):
        print(f"Loading model: {model_path}")
        model = SwinSeg()  # Assicurati che questa classe sia definita correttamente
        model.load_weights(model_path)
        model = model.to(args['device'])
        model.eval()

        with torch.no_grad():
            output = model(img_tensor.to(args['device']))
        segmentation = output.squeeze().cpu().numpy()
        return segmentation

    # Funzione per ottenere il bounding box dalla segmentazione
    def get_bounding_box(segmentation, img):
        binary_mask = (segmentation > 0.5).astype(np.uint8)
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if len(contours) == 0:
            return None, None, None, None
        largest_contour = max(contours, key=cv2.contourArea)
        x, y, w, h = cv2.boundingRect(largest_contour)

        # Scala il bounding box in base alla dimensione originale dell'immagine
        orig_width, orig_height = img.size
        x_scale = orig_width / 224
        y_scale = orig_height / 224
        x, y, w, h = int(x * x_scale), int(y * y_scale), int(w * x_scale), int(h * y_scale)
        
        return x, y, w, h

    # Funzione per visualizzare i risultati
    def plot_results(segmentation, img, model_name, box_color):
        x, y, w, h = get_bounding_box(segmentation, img)

        # Crea una copia dell'immagine con la bounding box
        img_with_box = img.copy()
        if x is not None:  # Se c'è una bounding box valida
            draw = ImageDraw.Draw(img_with_box)
            draw.rectangle([x, y, x+w, y+h], outline=box_color, width=3)

        # Plot dei risultati con dimensioni 15x5 per ogni immagine
        plt.figure(figsize=(15, 5))

        # Immagine normalizzata
        plt.subplot(1, 4, 1)
        img_normalized = img_tensor.squeeze().cpu().numpy().transpose(1, 2, 0)
        plt.imshow(img_normalized)
        plt.title('Img Normalized')
        plt.axis('off')

        # Segmentazione
        plt.subplot(1, 4, 2)
        plt.imshow(segmentation, cmap='gray')
        plt.title(f'Segmentation ({model_name})')
        plt.axis('off')

        # Immagine originale
        plt.subplot(1, 4, 3)
        plt.imshow(img)
        plt.title('Original Image')
        plt.axis('off')

        # Immagine con bounding box
        plt.subplot(1, 4, 4)
        plt.imshow(img_with_box)
        plt.title(f'Bounding Box ({model_name})')
        plt.axis('off')

        plt.tight_layout()
        plt.show()

    # Esegui il modello "last"
    segmentation_last = run_model(os.path.join(args['save_dir'], 'model_best_val_iou.pt'))
    plot_results(segmentation_last, img, "last model", "red")

    # Esegui il modello "best IoU"
    segmentation_best = run_model(os.path.join(args['save_dir'], 'model_best_test_iou.pt'))
    plot_results(segmentation_best, img, "best IoU model", "blue")

test_seg()
# Out:
# Opening: cju7ejm2l2ncl0801wq6y84nw.jpg
# Loading model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Loading pre-trained: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Loading model: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Loading pre-trained: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_test_iou.pt
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Test with duplicates
# #### For having another type of validation we want to use another dataset given by the ISIC challenge 2018. The number of images of this dataset is 1511.
# ####

# %%
# Funzione per formattare i valori in percentuale
def format_percentage(value):
    return f"{value * 100:.2f}"

# Funzione per calcolare Sensitivity e Specificity
def calculate_sensitivity_specificity(y_true, y_pred):
    TP = ((y_true == 1) & (y_pred == 1)).sum()
    TN = ((y_true == 0) & (y_pred == 0)).sum()
    FP = ((y_true == 0) & (y_pred == 1)).sum()
    FN = ((y_true == 1) & (y_pred == 0)).sum()
    
    sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    return sensitivity, specificity

# Funzione per plottare la confusion matrix
def plot_confusion_matrix(cm, class_names, title="Confusion Matrix", save_path=None):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(title)
    if save_path:
        plt.savefig(save_path)
        print(f"Confusion Matrix salvata in: {save_path}")
    plt.show()

# %%
# Caricamento del modello per la classificazione multiclasse
device = args["device"]
model_path = os.path.join(args['save_dir'], 'model_best_val_bin+multi.pt')

# Definisci il modello per la classificazione multiclasse
model = SwinClassification(num_classes_multiclass=args['num_classes'], num_classes_binary=2)
model.load_state_dict(torch.load(model_path, map_location=device))
model = model.to(device)
model.eval()

# Inizializza i tensori per le predizioni e le etichette vere
predlist_test_multi = torch.zeros(0, dtype=torch.long, device='cpu')
labels_multi_multi = torch.zeros(0, dtype=torch.long, device='cpu')

# Probabilità per calcolo ROC e AUC
proba_test_multi = torch.zeros(0, device='cpu')

# Esegui il test senza gradiente
with torch.no_grad():
    for i, (inputs, labels_multi, labels_bin) in enumerate(test_loader):  # Usa test_loader per la classificazione
        inputs = inputs.to(device)
        labels_multi = labels_multi.to(device)

        # Ottieni le predizioni del modello
        multiclass_output, _ = model(inputs)  # Prendi solo l'output multiclasse
        preds_multi = torch.argmax(multiclass_output, dim=1)  # Predizione della classe
        proba_test_multi = torch.cat([proba_test_multi, multiclass_output.softmax(dim=1).cpu()])
        
        # Append batch prediction results
        predlist_test_multi = torch.cat([predlist_test_multi, preds_multi.view(-1).cpu()])
        labels_multi_multi = torch.cat([labels_multi_multi, labels_multi.view(-1).cpu()])

# Conversione dei tensori in numpy per l'elaborazione successiva
predlist_test_multi = predlist_test_multi.numpy()
labels_multi_multi = labels_multi_multi.numpy()
proba_test_multi = proba_test_multi.numpy()

# Confusion Matrix per la classificazione multiclasse
conf_matrix = confusion_matrix(labels_multi_multi, predlist_test_multi)

# Definisci i nomi delle classi per la classificazione multiclasse
class_names = ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']

# Plot della confusion matrix
cm_save_path = os.path.join(args['save_dir'], 'Test_confusion_matrix.png')
plot_confusion_matrix(conf_matrix, class_names, save_path=cm_save_path)

# Calcolo delle metriche: ROC, AUC, Sensitivity e Specificity
roc_auc_dict = {}
sensitivity_dict = {}
specificity_dict = {}

for i, class_name in enumerate(class_names):
    y_true = (labels_multi_multi == i).astype(int)  # Verità per la classe corrente (one-vs-all)
    y_score = proba_test_multi[:, i]  # Probabilità per la classe corrente
    
    # ROC AUC
    if len(set(y_true)) > 1:  # Calcola solo se ci sono sia 0 che 1 nella classe
        roc_auc_dict[class_name] = roc_auc_score(y_true, y_score)
    
    # Sensitivity e Specificity
    y_pred = (predlist_test_multi == i).astype(int)
    sensitivity, specificity = calculate_sensitivity_specificity(y_true, y_pred)
    sensitivity_dict[class_name] = sensitivity
    specificity_dict[class_name] = specificity

# Calcolo delle AUC totali (macro e weighted)
y_true_binarized = label_binarize(labels_multi_multi, classes=list(range(len(class_names))))  # Binarizza i target
auc_macro = roc_auc_score(y_true_binarized, proba_test_multi, average="macro", multi_class="ovr")
auc_weighted = roc_auc_score(y_true_binarized, proba_test_multi, average="weighted", multi_class="ovr")

# Report di classificazione
report = classification_report(labels_multi_multi, predlist_test_multi, target_names=class_names, output_dict=True)

# Formattazione del report
formatted_report = "                       precision   recall   f1-score   support\n\n"
for class_name in class_names:
    precision = format_percentage(report[class_name]['precision'])
    recall = format_percentage(report[class_name]['recall'])
    f1_score = format_percentage(report[class_name]['f1-score'])
    support = report[class_name]['support']
    formatted_report += f"{class_name:<20}{precision:>9}    {recall:>6}    {f1_score:>8}   {support:>8}\n"

# Aggiungi le medie, l'accuratezza e le AUC totali
accuracy = format_percentage(report['accuracy'])
formatted_report += f"\naccuracy                           {accuracy:>6}\n"
formatted_report += f"\nAUC Totale (Macro-Average): {auc_macro:.4f}\n"
formatted_report += f"AUC Totale (Weighted-Average): {auc_weighted:.4f}\n"

# Aggiungi ROC AUC, Sensitivity e Specificity
formatted_report += "\nROC AUC per classe:\n"
for class_name, auc_value in roc_auc_dict.items():
    formatted_report += f"{class_name:<20}{auc_value:.4f}\n"

formatted_report += "\nSensitivity per classe:\n"
for class_name, sensitivity in sensitivity_dict.items():
    formatted_report += f"{class_name:<20}{sensitivity:.4f}\n"

formatted_report += "\nSpecificity per classe:\n"
for class_name, specificity in specificity_dict.items():
    formatted_report += f"{class_name:<20}{specificity:.4f}\n"

# Stampa diretta delle metriche
print("\n*** METRICHE DI CLASSIFICAZIONE ***")
print(formatted_report)

# Salva il report in un file
report_path = os.path.join(args['save_dir'], 'Test_classification_report.txt')
with open(report_path, 'w') as f:
    f.write(formatted_report)
print(f"Report salvato in: {report_path}")

# ROC per ogni classe
plt.figure(figsize=(12, 8))
for i, class_name in enumerate(class_names):
    y_true = (labels_multi_multi == i).astype(int)
    y_score = proba_test_multi[:, i]
    
    if len(set(y_true)) > 1:  # Calcola solo se ci sono sia 0 che 1 nella classe
        fpr, tpr, _ = roc_curve(y_true, y_score)
        plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc_dict[class_name]:.4f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonale
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve per Classe')
plt.legend(loc='lower right')

# Salva il plot per le classi
roc_classes_path = os.path.join(args['save_dir'], 'Test_roc_curve_classes.png')
plt.savefig(roc_classes_path)
plt.close()
print(f"ROC Curve per classe salvata in: {roc_classes_path}")

# Macro e Weighted ROC
plt.figure(figsize=(12, 8))

# Macro-Average Curve
fpr_macro = np.linspace(0, 1, 100)
tpr_macro = np.zeros_like(fpr_macro)
for i in range(len(class_names)):
    y_true = (labels_multi_multi == i).astype(int)
    y_score = proba_test_multi[:, i]
    
    if len(set(y_true)) > 1:
        fpr, tpr, _ = roc_curve(y_true, y_score)
        tpr_interp = np.interp(fpr_macro, fpr, tpr)  # Interpolazione
        tpr_macro += tpr_interp
tpr_macro /= len(class_names)
auc_macro_curve = auc(fpr_macro, tpr_macro)
plt.plot(fpr_macro, tpr_macro, 'r--', label=f"Macro-Average ROC (AUC = {auc_macro_curve:.4f})")

# Weighted-Average Curve
fpr_weighted = np.linspace(0, 1, 100)
tpr_weighted = np.zeros_like(fpr_weighted)
weights = [sum(labels_multi_multi == i) for i in range(len(class_names))]  # Numero di esempi per classe

for i in range(len(class_names)):
    y_true = (labels_multi_multi == i).astype(int)
    y_score = proba_test_multi[:, i]
    
    if len(set(y_true)) > 1:
        fpr, tpr, _ = roc_curve(y_true, y_score)
        tpr_interp = np.interp(fpr_weighted, fpr, tpr)  # Interpolazione
        tpr_weighted += tpr_interp * weights[i]
tpr_weighted /= sum(weights)
auc_weighted_curve = auc(fpr_weighted, tpr_weighted)
plt.plot(fpr_weighted, tpr_weighted, 'g--', label=f"Weighted-Average ROC (AUC = {auc_weighted_curve:.4f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonale
plt.xlabel('Specificity')
plt.ylabel('Sensitivity')
plt.title('Macro e Weighted ROC Curve')
plt.legend(loc='lower right')

# Salva il plot per Macro e Weighted
roc_macro_weighted_path = os.path.join(args['save_dir'], 'Test_roc_curve_macro_weighted.png')
plt.savefig(roc_macro_weighted_path)
plt.close()
print(f"Macro e Weighted ROC Curve salvata in: {roc_macro_weighted_path}")
# Out:
# Confusion Matrix salvata in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/Test_confusion_matrix.png
# *** METRICHE DI CLASSIFICAZIONE ***
#                        precision   recall   f1-score   support
#
# dyed-lifted-polyps      97.92     92.16       94.95       51.0
# dyed-resection-margins    92.59     98.04       95.24       51.0
# esophagitis             91.11     78.85       84.54       52.0
# normal-cecum            96.23    100.00       98.08       51.0
# normal-pylorus          98.11    100.00       99.05       52.0
# normal-z-line           81.36     92.31       86.49       52.0
# polyps                  95.83     90.20       92.93       51.0
# ulcerative-colitis      96.08     96.08       96.08       51.0
#
# accuracy                            93.43
#
# AUC Totale (Macro-Average): 0.9924
# AUC Totale (Weighted-Average): 0.9924
#
# ROC AUC per classe:
# dyed-lifted-polyps  0.9990
# dyed-resection-margins0.9991
# esophagitis         0.9717
# normal-cecum        0.9999
# normal-pylorus      0.9998
# normal-z-line       0.9791
# polyps              0.9928
# ulcerative-colitis  0.9980
#
# Sensitivity per classe:
# dyed-lifted-polyps  0.9216
# dyed-resection-margins0.9804
# esophagitis         0.7885
# normal-cecum        1.0000
# normal-pylorus      1.0000
# normal-z-line       0.9231
# polyps              0.9020
# ulcerative-colitis  0.9608
#
# Specificity per classe:
# dyed-lifted-polyps  0.9972
# dyed-resection-margins0.9889
# esophagitis         0.9889
# normal-cecum        0.9944
# normal-pylorus      0.9972
# normal-z-line       0.9694
# polyps              0.9944
# ulcerative-colitis  0.9944
#
# Report salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/Test_classification_report.txt
# ROC Curve per classe salvata in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/Test_roc_curve_classes.png
# Macro e Weighted ROC Curve salvata in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/Test_roc_curve_macro_weighted.png

# %% [markdown]
# # t-SNE to represent multidimensional samples in 2D

# %%
def validate_tsne(model, val_loader, device):
    print('Start validation...')
    model.eval()

    all_labels = []
    all_features = []
    with torch.no_grad():
        for inputs, labels_multi, labels_bin in tqdm(val_loader):
            inputs = inputs.to(device)

            multiclass_output, binary_output = model(inputs)
            features = model.features

            all_labels.extend(labels_multi.cpu().numpy())
            all_features.extend(features.cpu().numpy())
            #print("all_features:", len(all_features))

    return np.array(all_labels), np.array(all_features)

# %%
device = args["device"]
model_path = os.path.join(args['save_dir'], 'model_best_val_bin+multi.pt')
model.load_state_dict(torch.load(model_path, map_location=device))
model = model.to(device)

# %%
# Definire una funzione hook per memorizzare le features
def hook_fn(module, input, output):
    # Memorizza l'output (features in input al layer finale prima della classificazione)
    model.features = output

# Registrare l'hook sul layer desiderato (prima del penultimo nn.Linear)
hook = model.head[4].register_forward_hook(hook_fn)

# %%
# Funzione per il plot del t-SNE con solo la legenda con i pallini colorati
def plot_tsne(features, labels, class_names):
    tsne = TSNE(n_components=2, random_state=42)
    features_2d = tsne.fit_transform(features)

    plt.figure(figsize=(10, 5))
    
    # Crea il grafico t-SNE
    scatter = plt.scatter(features_2d[:, 0], features_2d[:, 1], c=labels, cmap='tab10', alpha=0.7)
    
    # Crea la legenda con i pallini colorati e i nomi delle classi
    handles, _ = scatter.legend_elements(prop="colors", alpha=0.7)
    legend_labels = [class_names[int(i)] for i in np.unique(labels)]
    
    # Aggiungi la legenda accanto al grafico con i pallini colorati
    plt.legend(handles, legend_labels, title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title_fontsize=14)
    
    plt.title('t-SNE plot of model features')

    # Usa un layout che eviti la sovrapposizione della legenda con il grafico
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Crea spazio a destra per la legenda
    
    plt.show()

# Ottieni le labels e le features dal modello
labels, features = validate_tsne(model, val_loader, device)

# Nomi delle classi (puoi modificare questo elenco in base alle tue classi)
class_names = ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']

# Visualizza il t-SNE plot con legenda
plot_tsne(features, labels, class_names)
# Out:
# Start validation...
# 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]

# %% [markdown]
# # Second Fine-Tuning on Multiclass Classification

# %%
# Funzione per tracciare e salvare i grafici di loss e accuracy
def plot_and_save_metrics_multi2(metrics_data, save_dir):
    epochs = metrics_data['epoch']

    # Loss plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, metrics_data['train_loss_mult'], label='Train Loss')
    plt.plot(epochs, metrics_data['val_loss_multi'], label='Validation Loss')
    plt.plot(epochs, metrics_data['test_loss_multi'], label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Multiclass Loss over Epochs')
    plt.legend()
    loss_plot_path = os.path.join(save_dir, 'multiclass_loss_plot2.png')
    plt.savefig(loss_plot_path)
    plt.close()
    print(f"Loss plot salvato in: {loss_plot_path}")

    # Accuracy plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, metrics_data['train_acc_multi'], label='Train Accuracy')
    plt.plot(epochs, metrics_data['val_acc_multi'], label='Validation Accuracy')
    plt.plot(epochs, metrics_data['test_acc_multi'], label='Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Multiclass Accuracy over Epochs')
    plt.legend()
    acc_plot_path = os.path.join(save_dir, 'multiclass_accuracy_plot2.png')
    plt.savefig(acc_plot_path)
    plt.close()
    print(f"Accuracy plot salvato in: {acc_plot_path}")

# %%
# Funzione principale per il training multi-classe
def run_multiclass_training():
    # Utilizza i dataset di classificazione definiti in args per multi-classe
    train_dataset = BinaryImageFolder(
        args['train_dir_class'], transform=train_transforms, binary=False, multi=True)
    
    val_dataset = BinaryImageFolder(
        args['val_dir_class'], transform=val_transforms, binary=False, multi=True)
    
    test_dataset = BinaryImageFolder(
        args['test_dir_class'], transform=test_transforms, binary=False, multi=True)
    
    # Creazione dei DataLoader per training, validazione e test
    train_loader = DataLoader(train_dataset, batch_size=args['batch_size'], shuffle=True, num_workers=8)
    val_loader = DataLoader(val_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)
    test_loader = DataLoader(test_dataset, batch_size=args['batch_size'], shuffle=False, num_workers=8)

    print("\nNumero di esempi nel dataset di training:", len(train_dataset))

    # Inizializza le metriche
    metrics = Metrics(["epoch", "lr", 
                       "train_loss_mult", "train_loss_bin", 
                       "train_acc_multi", "train_acc_bin", 
                       "val_loss_multi", "val_loss_bin", 
                       "val_acc_multi", "val_acc_bin",
                       "test_loss_multi", "test_loss_bin",
                       "test_acc_multi", "test_acc_bin",
                       "best_val_acc", "conf_matrix"])

# Caricamento del modello di segmentazione pre-addestrato e conversione a classificazione
    print("Caricamento del modello di segmentazione pre-addestrato...")
    model = SwinSeg()  # Modello di segmentazione pre-addestrato
    model.load_weights(os.path.join(args['save_dir'], 'model_best_val_iou.pt'))  # Carica i pesi del modello di segmentazione
    
    print("Conversione del modello di segmentazione a modello di classificazione...")
    model = model.convert_to_classification(num_classes_multiclass=args['num_classes'], num_classes_binary=2)
    model = model.to(args['device'])
    
    optimizer = optim.Adam(model.parameters(), lr=args['lr'])
    lambda_lr = lambda epoch: 0.95 ** epoch
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)

    best_val_acc_multi = 0  # Variabile per tracciare il miglior valore di accuratezza di validazione multi-classe
    
    for epoch in range(100):  # Imposta il numero di epoche
        # Fase di training (multi-classe)
        train_loss_multi, train_loss_binaria, train_acc_multi, train_acc_bin = train_one_epoch_multi(
            model, train_loader, optimizer, args['device'])
        
        # Fase di validazione (multi-classe)
        val_loss_multi, val_loss_binaria, val_acc_multi, val_acc_bin, val_conf_matrix = validate_multi(
            model, val_loader, args['device'])

        # Fase di test (multi-classe)
        test_loss_multi, test_loss_binaria, test_acc_multi, test_acc_bin, test_conf_matrix = validate_multi(
            model, test_loader, args['device'])
        
        scheduler.step()

        # Output dei risultati
        print(f'Epoca {epoch+1}, Loss Train Multi: {train_loss_multi:.4f}, '
              f'Acc Train Multi: {to_cpu(train_acc_multi):.4f}, Loss Val Multi: {val_loss_multi:.4f}, '
              f'Acc Val Multi: {to_cpu(val_acc_multi):.4f}, Loss Test Multi: {test_loss_multi:.4f}, '
              f'Acc Test Multi: {to_cpu(test_acc_multi):.4f}')
        
        # Salva il modello se l'accuratezza di validazione multi-classe è migliorata
        if val_acc_multi > best_val_acc_multi:
            print("Miglior acc val multi-classe, salvataggio del modello...")
            best_val_acc_multi = to_cpu(val_acc_multi)
            torch.save(model.state_dict(), os.path.join(args['save_dir'], f'model_best_val_bin+multi_exp2.pt'))
        
        # Salva il modello ad ogni epoca
        torch.save(model.state_dict(), os.path.join(args['save_dir'], f'model_last_bin+multi_exp2.pt'))

        # Aggiorna le metriche
        lr = optimizer.param_groups[0]["lr"]
        metrics.add_row([
            epoch+1, 
            lr, 
            train_loss_multi, 
            train_loss_binaria, 
            to_cpu(train_acc_multi),   # Conversione con funzione helper
            to_cpu(train_acc_bin),     # Conversione con funzione helper
            val_loss_multi,
            val_loss_binaria,
            to_cpu(val_acc_multi),     # Conversione con funzione helper
            to_cpu(val_acc_bin),       # Conversione con funzione helper
            test_loss_multi, 
            test_loss_binaria, 
            to_cpu(test_acc_multi),    # Conversione con funzione helper
            to_cpu(test_acc_bin),      # Conversione con funzione helper
            best_val_acc_multi,
            f"{test_conf_matrix}",
        ])
        metrics.save_to_csv(os.path.join(args['save_dir'], f"metrics_bin+multi5_exp2.csv"))

    # Salva i plot di loss e accuracy
    metrics_data = pd.read_csv(os.path.join(args['save_dir'], "metrics_bin+multi5_exp2.csv"))
    plot_and_save_metrics_multi2(metrics_data, args['save_dir'])
    
    print("Training completato.")

# Esegui la funzione per il training multi-classe
run_multiclass_training()
# Out:
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/train/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/validation/
# ***Loading:/home/jovyan/nfs/mgallazzi/datasets/Kvasir_dataset/Kvasir_dataset_classification/test/
#
# Numero di esempi nel dataset di training: 3000
# Caricamento del modello di segmentazione pre-addestrato...
# Loading pre-trained: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/model_best_val_iou.pt
# Conversione del modello di segmentazione a modello di classificazione...
# Start training...
# Start validation...
# Start validation...
# Epoca 1, Loss Train Multi: 0.4463, Acc Train Multi: 0.8707, Loss Val Multi: 0.0021, Acc Val Multi: 0.9217, Loss Test Multi: 0.0016, Acc Test Multi: 0.9350
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 2, Loss Train Multi: 0.0983, Acc Train Multi: 0.9643, Loss Val Multi: 0.0016, Acc Val Multi: 0.9383, Loss Test Multi: 0.0013, Acc Test Multi: 0.9425
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 3, Loss Train Multi: 0.0534, Acc Train Multi: 0.9810, Loss Val Multi: 0.0025, Acc Val Multi: 0.9317, Loss Test Multi: 0.0022, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 4, Loss Train Multi: 0.0519, Acc Train Multi: 0.9813, Loss Val Multi: 0.0021, Acc Val Multi: 0.9217, Loss Test Multi: 0.0022, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 5, Loss Train Multi: 0.0323, Acc Train Multi: 0.9900, Loss Val Multi: 0.0019, Acc Val Multi: 0.9317, Loss Test Multi: 0.0021, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 6, Loss Train Multi: 0.0275, Acc Train Multi: 0.9900, Loss Val Multi: 0.0023, Acc Val Multi: 0.9267, Loss Test Multi: 0.0025, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 7, Loss Train Multi: 0.0463, Acc Train Multi: 0.9860, Loss Val Multi: 0.0019, Acc Val Multi: 0.9183, Loss Test Multi: 0.0024, Acc Test Multi: 0.9075
# Start training...
# Start validation...
# Start validation...
# Epoca 8, Loss Train Multi: 0.0529, Acc Train Multi: 0.9803, Loss Val Multi: 0.0015, Acc Val Multi: 0.9383, Loss Test Multi: 0.0015, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 9, Loss Train Multi: 0.0265, Acc Train Multi: 0.9923, Loss Val Multi: 0.0017, Acc Val Multi: 0.9400, Loss Test Multi: 0.0021, Acc Test Multi: 0.9450
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 10, Loss Train Multi: 0.0131, Acc Train Multi: 0.9957, Loss Val Multi: 0.0019, Acc Val Multi: 0.9450, Loss Test Multi: 0.0026, Acc Test Multi: 0.9475
# Miglior acc val multi-classe, salvataggio del modello...
# Start training...
# Start validation...
# Start validation...
# Epoca 11, Loss Train Multi: 0.0193, Acc Train Multi: 0.9927, Loss Val Multi: 0.0023, Acc Val Multi: 0.9383, Loss Test Multi: 0.0025, Acc Test Multi: 0.9450
# Start training...
# Start validation...
# Start validation...
# Epoca 12, Loss Train Multi: 0.0151, Acc Train Multi: 0.9957, Loss Val Multi: 0.0022, Acc Val Multi: 0.9400, Loss Test Multi: 0.0026, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 13, Loss Train Multi: 0.0127, Acc Train Multi: 0.9957, Loss Val Multi: 0.0023, Acc Val Multi: 0.9333, Loss Test Multi: 0.0026, Acc Test Multi: 0.9500
# Start training...
# Start validation...
# Start validation...
# Epoca 14, Loss Train Multi: 0.0117, Acc Train Multi: 0.9967, Loss Val Multi: 0.0025, Acc Val Multi: 0.9367, Loss Test Multi: 0.0025, Acc Test Multi: 0.9525
# Start training...
# Start validation...
# Start validation...
# Epoca 15, Loss Train Multi: 0.0120, Acc Train Multi: 0.9957, Loss Val Multi: 0.0031, Acc Val Multi: 0.9267, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 16, Loss Train Multi: 0.0139, Acc Train Multi: 0.9953, Loss Val Multi: 0.0024, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 17, Loss Train Multi: 0.0098, Acc Train Multi: 0.9967, Loss Val Multi: 0.0030, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 18, Loss Train Multi: 0.0108, Acc Train Multi: 0.9963, Loss Val Multi: 0.0025, Acc Val Multi: 0.9317, Loss Test Multi: 0.0028, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 19, Loss Train Multi: 0.0096, Acc Train Multi: 0.9967, Loss Val Multi: 0.0027, Acc Val Multi: 0.9250, Loss Test Multi: 0.0031, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 20, Loss Train Multi: 0.0085, Acc Train Multi: 0.9980, Loss Val Multi: 0.0033, Acc Val Multi: 0.9167, Loss Test Multi: 0.0027, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 21, Loss Train Multi: 0.0100, Acc Train Multi: 0.9970, Loss Val Multi: 0.0025, Acc Val Multi: 0.9167, Loss Test Multi: 0.0028, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 22, Loss Train Multi: 0.0058, Acc Train Multi: 0.9990, Loss Val Multi: 0.0027, Acc Val Multi: 0.9200, Loss Test Multi: 0.0029, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 23, Loss Train Multi: 0.0086, Acc Train Multi: 0.9977, Loss Val Multi: 0.0027, Acc Val Multi: 0.9333, Loss Test Multi: 0.0030, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 24, Loss Train Multi: 0.0098, Acc Train Multi: 0.9980, Loss Val Multi: 0.0028, Acc Val Multi: 0.9350, Loss Test Multi: 0.0028, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 25, Loss Train Multi: 0.0052, Acc Train Multi: 0.9983, Loss Val Multi: 0.0025, Acc Val Multi: 0.9417, Loss Test Multi: 0.0028, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 26, Loss Train Multi: 0.0030, Acc Train Multi: 0.9993, Loss Val Multi: 0.0024, Acc Val Multi: 0.9417, Loss Test Multi: 0.0033, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 27, Loss Train Multi: 0.0077, Acc Train Multi: 0.9980, Loss Val Multi: 0.0032, Acc Val Multi: 0.9367, Loss Test Multi: 0.0032, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 28, Loss Train Multi: 0.0052, Acc Train Multi: 0.9990, Loss Val Multi: 0.0026, Acc Val Multi: 0.9317, Loss Test Multi: 0.0031, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 29, Loss Train Multi: 0.0026, Acc Train Multi: 1.0000, Loss Val Multi: 0.0030, Acc Val Multi: 0.9283, Loss Test Multi: 0.0031, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 30, Loss Train Multi: 0.0047, Acc Train Multi: 0.9987, Loss Val Multi: 0.0029, Acc Val Multi: 0.9333, Loss Test Multi: 0.0031, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 31, Loss Train Multi: 0.0072, Acc Train Multi: 0.9980, Loss Val Multi: 0.0035, Acc Val Multi: 0.9250, Loss Test Multi: 0.0032, Acc Test Multi: 0.9200
# Start training...
# Start validation...
# Start validation...
# Epoca 32, Loss Train Multi: 0.0043, Acc Train Multi: 0.9987, Loss Val Multi: 0.0030, Acc Val Multi: 0.9350, Loss Test Multi: 0.0033, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 33, Loss Train Multi: 0.0020, Acc Train Multi: 0.9993, Loss Val Multi: 0.0033, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 34, Loss Train Multi: 0.0018, Acc Train Multi: 1.0000, Loss Val Multi: 0.0033, Acc Val Multi: 0.9300, Loss Test Multi: 0.0031, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 35, Loss Train Multi: 0.0018, Acc Train Multi: 0.9997, Loss Val Multi: 0.0035, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 36, Loss Train Multi: 0.0051, Acc Train Multi: 0.9987, Loss Val Multi: 0.0038, Acc Val Multi: 0.9233, Loss Test Multi: 0.0031, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 37, Loss Train Multi: 0.0017, Acc Train Multi: 1.0000, Loss Val Multi: 0.0031, Acc Val Multi: 0.9333, Loss Test Multi: 0.0031, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 38, Loss Train Multi: 0.0071, Acc Train Multi: 0.9980, Loss Val Multi: 0.0030, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 39, Loss Train Multi: 0.0044, Acc Train Multi: 0.9993, Loss Val Multi: 0.0038, Acc Val Multi: 0.9300, Loss Test Multi: 0.0033, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 40, Loss Train Multi: 0.0034, Acc Train Multi: 0.9990, Loss Val Multi: 0.0038, Acc Val Multi: 0.9250, Loss Test Multi: 0.0034, Acc Test Multi: 0.9450
# Start training...
# Start validation...
# Start validation...
# Epoca 41, Loss Train Multi: 0.0030, Acc Train Multi: 0.9993, Loss Val Multi: 0.0031, Acc Val Multi: 0.9317, Loss Test Multi: 0.0033, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 42, Loss Train Multi: 0.0019, Acc Train Multi: 0.9997, Loss Val Multi: 0.0029, Acc Val Multi: 0.9333, Loss Test Multi: 0.0033, Acc Test Multi: 0.9275
# Start training...
# Start validation...
# Start validation...
# Epoca 43, Loss Train Multi: 0.0030, Acc Train Multi: 0.9990, Loss Val Multi: 0.0030, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 44, Loss Train Multi: 0.0022, Acc Train Multi: 0.9993, Loss Val Multi: 0.0029, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 45, Loss Train Multi: 0.0033, Acc Train Multi: 0.9993, Loss Val Multi: 0.0029, Acc Val Multi: 0.9383, Loss Test Multi: 0.0033, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 46, Loss Train Multi: 0.0039, Acc Train Multi: 0.9987, Loss Val Multi: 0.0030, Acc Val Multi: 0.9333, Loss Test Multi: 0.0033, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 47, Loss Train Multi: 0.0041, Acc Train Multi: 0.9983, Loss Val Multi: 0.0029, Acc Val Multi: 0.9233, Loss Test Multi: 0.0033, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 48, Loss Train Multi: 0.0022, Acc Train Multi: 0.9990, Loss Val Multi: 0.0033, Acc Val Multi: 0.9283, Loss Test Multi: 0.0032, Acc Test Multi: 0.9275
# Start training...
# Start validation...
# Start validation...
# Epoca 49, Loss Train Multi: 0.0036, Acc Train Multi: 0.9990, Loss Val Multi: 0.0032, Acc Val Multi: 0.9317, Loss Test Multi: 0.0033, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 50, Loss Train Multi: 0.0042, Acc Train Multi: 0.9993, Loss Val Multi: 0.0034, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9425
# Start training...
# Start validation...
# Start validation...
# Epoca 51, Loss Train Multi: 0.0032, Acc Train Multi: 0.9987, Loss Val Multi: 0.0034, Acc Val Multi: 0.9317, Loss Test Multi: 0.0031, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 52, Loss Train Multi: 0.0011, Acc Train Multi: 1.0000, Loss Val Multi: 0.0032, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 53, Loss Train Multi: 0.0033, Acc Train Multi: 0.9987, Loss Val Multi: 0.0032, Acc Val Multi: 0.9233, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 54, Loss Train Multi: 0.0036, Acc Train Multi: 0.9993, Loss Val Multi: 0.0029, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 55, Loss Train Multi: 0.0019, Acc Train Multi: 0.9993, Loss Val Multi: 0.0032, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 56, Loss Train Multi: 0.0048, Acc Train Multi: 0.9987, Loss Val Multi: 0.0030, Acc Val Multi: 0.9350, Loss Test Multi: 0.0032, Acc Test Multi: 0.9300
# Start training...
# Start validation...
# Start validation...
# Epoca 57, Loss Train Multi: 0.0029, Acc Train Multi: 0.9993, Loss Val Multi: 0.0030, Acc Val Multi: 0.9350, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 58, Loss Train Multi: 0.0037, Acc Train Multi: 0.9987, Loss Val Multi: 0.0032, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 59, Loss Train Multi: 0.0013, Acc Train Multi: 1.0000, Loss Val Multi: 0.0035, Acc Val Multi: 0.9267, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 60, Loss Train Multi: 0.0022, Acc Train Multi: 0.9993, Loss Val Multi: 0.0034, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 61, Loss Train Multi: 0.0016, Acc Train Multi: 0.9993, Loss Val Multi: 0.0033, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 62, Loss Train Multi: 0.0013, Acc Train Multi: 0.9997, Loss Val Multi: 0.0034, Acc Val Multi: 0.9283, Loss Test Multi: 0.0033, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 63, Loss Train Multi: 0.0025, Acc Train Multi: 0.9993, Loss Val Multi: 0.0030, Acc Val Multi: 0.9367, Loss Test Multi: 0.0033, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 64, Loss Train Multi: 0.0013, Acc Train Multi: 1.0000, Loss Val Multi: 0.0031, Acc Val Multi: 0.9333, Loss Test Multi: 0.0033, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 65, Loss Train Multi: 0.0028, Acc Train Multi: 0.9987, Loss Val Multi: 0.0031, Acc Val Multi: 0.9333, Loss Test Multi: 0.0033, Acc Test Multi: 0.9275
# Start training...
# Start validation...
# Start validation...
# Epoca 66, Loss Train Multi: 0.0013, Acc Train Multi: 0.9997, Loss Val Multi: 0.0034, Acc Val Multi: 0.9267, Loss Test Multi: 0.0033, Acc Test Multi: 0.9275
# Start training...
# Start validation...
# Start validation...
# Epoca 67, Loss Train Multi: 0.0018, Acc Train Multi: 0.9997, Loss Val Multi: 0.0034, Acc Val Multi: 0.9283, Loss Test Multi: 0.0033, Acc Test Multi: 0.9275
# Start training...
# Start validation...
# Start validation...
# Epoca 68, Loss Train Multi: 0.0028, Acc Train Multi: 0.9990, Loss Val Multi: 0.0034, Acc Val Multi: 0.9283, Loss Test Multi: 0.0033, Acc Test Multi: 0.9275
# Start training...
# Start validation...
# Start validation...
# Epoca 69, Loss Train Multi: 0.0015, Acc Train Multi: 0.9993, Loss Val Multi: 0.0035, Acc Val Multi: 0.9300, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 70, Loss Train Multi: 0.0017, Acc Train Multi: 0.9997, Loss Val Multi: 0.0035, Acc Val Multi: 0.9300, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 71, Loss Train Multi: 0.0029, Acc Train Multi: 0.9990, Loss Val Multi: 0.0031, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9325
# Start training...
# Start validation...
# Start validation...
# Epoca 72, Loss Train Multi: 0.0013, Acc Train Multi: 0.9997, Loss Val Multi: 0.0030, Acc Val Multi: 0.9267, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 73, Loss Train Multi: 0.0014, Acc Train Multi: 0.9997, Loss Val Multi: 0.0034, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 74, Loss Train Multi: 0.0016, Acc Train Multi: 0.9997, Loss Val Multi: 0.0033, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 75, Loss Train Multi: 0.0017, Acc Train Multi: 0.9997, Loss Val Multi: 0.0030, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 76, Loss Train Multi: 0.0009, Acc Train Multi: 1.0000, Loss Val Multi: 0.0032, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 77, Loss Train Multi: 0.0017, Acc Train Multi: 0.9990, Loss Val Multi: 0.0032, Acc Val Multi: 0.9283, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 78, Loss Train Multi: 0.0028, Acc Train Multi: 0.9990, Loss Val Multi: 0.0032, Acc Val Multi: 0.9333, Loss Test Multi: 0.0033, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 79, Loss Train Multi: 0.0010, Acc Train Multi: 1.0000, Loss Val Multi: 0.0032, Acc Val Multi: 0.9317, Loss Test Multi: 0.0033, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 80, Loss Train Multi: 0.0022, Acc Train Multi: 0.9997, Loss Val Multi: 0.0031, Acc Val Multi: 0.9267, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 81, Loss Train Multi: 0.0015, Acc Train Multi: 0.9990, Loss Val Multi: 0.0037, Acc Val Multi: 0.9317, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 82, Loss Train Multi: 0.0012, Acc Train Multi: 1.0000, Loss Val Multi: 0.0035, Acc Val Multi: 0.9367, Loss Test Multi: 0.0033, Acc Test Multi: 0.9450
# Start training...
# Start validation...
# Start validation...
# Epoca 83, Loss Train Multi: 0.0017, Acc Train Multi: 0.9993, Loss Val Multi: 0.0034, Acc Val Multi: 0.9283, Loss Test Multi: 0.0033, Acc Test Multi: 0.9475
# Start training...
# Start validation...
# Start validation...
# Epoca 84, Loss Train Multi: 0.0016, Acc Train Multi: 0.9997, Loss Val Multi: 0.0033, Acc Val Multi: 0.9317, Loss Test Multi: 0.0033, Acc Test Multi: 0.9475
# Start training...
# Start validation...
# Start validation...
# Epoca 85, Loss Train Multi: 0.0018, Acc Train Multi: 0.9990, Loss Val Multi: 0.0035, Acc Val Multi: 0.9317, Loss Test Multi: 0.0033, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 86, Loss Train Multi: 0.0023, Acc Train Multi: 0.9987, Loss Val Multi: 0.0037, Acc Val Multi: 0.9283, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 87, Loss Train Multi: 0.0013, Acc Train Multi: 0.9993, Loss Val Multi: 0.0034, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 88, Loss Train Multi: 0.0033, Acc Train Multi: 0.9987, Loss Val Multi: 0.0032, Acc Val Multi: 0.9283, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 89, Loss Train Multi: 0.0038, Acc Train Multi: 0.9987, Loss Val Multi: 0.0032, Acc Val Multi: 0.9283, Loss Test Multi: 0.0032, Acc Test Multi: 0.9350
# Start training...
# Start validation...
# Start validation...
# Epoca 90, Loss Train Multi: 0.0014, Acc Train Multi: 0.9997, Loss Val Multi: 0.0034, Acc Val Multi: 0.9300, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 91, Loss Train Multi: 0.0039, Acc Train Multi: 0.9990, Loss Val Multi: 0.0038, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9400
# Start training...
# Start validation...
# Start validation...
# Epoca 92, Loss Train Multi: 0.0008, Acc Train Multi: 1.0000, Loss Val Multi: 0.0035, Acc Val Multi: 0.9317, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...
# Epoca 93, Loss Train Multi: 0.0010, Acc Train Multi: 0.9997, Loss Val Multi: 0.0031, Acc Val Multi: 0.9333, Loss Test Multi: 0.0032, Acc Test Multi: 0.9375
# Start training...
# Start validation...
# Start validation...

# %%
# Caricamento del modello per la classificazione multiclasse
device = args["device"]
model_path = os.path.join(args['save_dir'], 'model_best_val_bin+multi_exp2.pt')

# Definisci il modello per la classificazione multiclasse
model = SwinClassification(num_classes_multiclass=args['num_classes'], num_classes_binary=2)
model.load_state_dict(torch.load(model_path, map_location=device))
model = model.to(device)
model.eval()

# Inizializza i tensori per le predizioni e le etichette vere
predlist_test_multi = torch.zeros(0, dtype=torch.long, device='cpu')
labels_multi_multi = torch.zeros(0, dtype=torch.long, device='cpu')

# Probabilità per calcolo ROC e AUC
proba_test_multi = torch.zeros(0, device='cpu')

# Esegui il test senza gradiente
with torch.no_grad():
    for i, (inputs, labels_multi, labels_bin) in enumerate(test_loader):  # Usa test_loader per la classificazione
        inputs = inputs.to(device)
        labels_multi = labels_multi.to(device)

        # Ottieni le predizioni del modello
        multiclass_output, _ = model(inputs)  # Prendi solo l'output multiclasse
        preds_multi = torch.argmax(multiclass_output, dim=1)  # Predizione della classe
        proba_test_multi = torch.cat([proba_test_multi, multiclass_output.softmax(dim=1).cpu()])
        
        # Append batch prediction results
        predlist_test_multi = torch.cat([predlist_test_multi, preds_multi.view(-1).cpu()])
        labels_multi_multi = torch.cat([labels_multi_multi, labels_multi.view(-1).cpu()])

# Conversione dei tensori in numpy per l'elaborazione successiva
predlist_test_multi = predlist_test_multi.numpy()
labels_multi_multi = labels_multi_multi.numpy()
proba_test_multi = proba_test_multi.numpy()

# Confusion Matrix per la classificazione multiclasse
conf_matrix = confusion_matrix(labels_multi_multi, predlist_test_multi)

# Definisci i nomi delle classi per la classificazione multiclasse
class_names = ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 
               'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']

# Plot della confusion matrix
cm_save_path = os.path.join(args['save_dir'], 'Test_confusion_matrix5_exp2.png')
plot_confusion_matrix(conf_matrix, class_names, save_path=cm_save_path)

# Calcolo delle metriche: ROC, AUC, Sensitivity e Specificity
roc_auc_dict = {}
sensitivity_dict = {}
specificity_dict = {}

for i, class_name in enumerate(class_names):
    y_true = (labels_multi_multi == i).astype(int)  # Verità per la classe corrente (one-vs-all)
    y_score = proba_test_multi[:, i]  # Probabilità per la classe corrente
    
    # ROC AUC
    if len(set(y_true)) > 1:  # Calcola solo se ci sono sia 0 che 1 nella classe
        roc_auc_dict[class_name] = roc_auc_score(y_true, y_score)
    
    # Sensitivity e Specificity
    y_pred = (predlist_test_multi == i).astype(int)
    sensitivity, specificity = calculate_sensitivity_specificity(y_true, y_pred)
    sensitivity_dict[class_name] = sensitivity
    specificity_dict[class_name] = specificity

# Report di classificazione
report = classification_report(labels_multi_multi, predlist_test_multi, target_names=class_names, output_dict=True)

# Formattazione del report
formatted_report = "                       precision   recall   f1-score   support\n\n"
for class_name in class_names:
    precision = format_percentage(report[class_name]['precision'])
    recall = format_percentage(report[class_name]['recall'])
    f1_score = format_percentage(report[class_name]['f1-score'])
    support = report[class_name]['support']
    formatted_report += f"{class_name:<20}{precision:>9}    {recall:>6}    {f1_score:>8}   {support:>8}\n"

# Aggiungi le medie e l'accuratezza
accuracy = format_percentage(report['accuracy'])
formatted_report += f"\naccuracy                           {accuracy:>6}\n"

# Aggiungi ROC AUC, Sensitivity e Specificity
formatted_report += "\nROC AUC per classe:\n"
for class_name, auc_value in roc_auc_dict.items():
    formatted_report += f"{class_name:<20}{auc_value:.4f}\n"

formatted_report += "\nSensitivity per classe:\n"
for class_name, sensitivity in sensitivity_dict.items():
    formatted_report += f"{class_name:<20}{sensitivity:.4f}\n"

formatted_report += "\nSpecificity per classe:\n"
for class_name, specificity in specificity_dict.items():
    formatted_report += f"{class_name:<20}{specificity:.4f}\n"

# Stampa diretta delle metriche
print("\n*** METRICHE DI CLASSIFICAZIONE ***")
print(formatted_report)

# Salva il report in un file
report_path = os.path.join(args['save_dir'], 'Test_classification_report5_exp2.txt')
with open(report_path, 'w') as f:
    f.write(formatted_report)
print(f"Report salvato in: {report_path}")

# Plot della curva ROC
plt.figure(figsize=(12, 8))
for i, class_name in enumerate(class_names):
    y_true = (labels_multi_multi == i).astype(int)
    y_score = proba_test_multi[:, i]
    
    if len(set(y_true)) > 1:  # Calcola solo se ci sono sia 0 che 1 nella classe
        fpr, tpr, _ = roc_curve(y_true, y_score)
        plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc_dict[class_name]:.4f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonale
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
roc_plot_path = os.path.join(args['save_dir'], 'Test_roc_curve5_exp2.png')
plt.savefig(roc_plot_path)
plt.close()
print(f"ROC Curve salvata in: {roc_plot_path}")
# Out:
# Confusion Matrix salvata in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/Test_confusion_matrix5_exp2.png
# *** METRICHE DI CLASSIFICAZIONE ***
#                        precision   recall   f1-score   support
#
# dyed-lifted-polyps      97.83     90.00       93.75       50.0
# dyed-resection-margins    90.74     98.00       94.23       50.0
# esophagitis             91.30     84.00       87.50       50.0
# normal-cecum           100.00    100.00      100.00       50.0
# normal-pylorus          98.04    100.00       99.01       50.0
# normal-z-line           85.19     92.00       88.46       50.0
# polyps                  97.96     96.00       96.97       50.0
# ulcerative-colitis      98.00     98.00       98.00       50.0
#
# accuracy                            94.75
#
# ROC AUC per classe:
# dyed-lifted-polyps  0.9975
# dyed-resection-margins0.9991
# esophagitis         0.9842
# normal-cecum        1.0000
# normal-pylorus      1.0000
# normal-z-line       0.9862
# polyps              0.9938
# ulcerative-colitis  0.9987
#
# Sensitivity per classe:
# dyed-lifted-polyps  0.9000
# dyed-resection-margins0.9800
# esophagitis         0.8400
# normal-cecum        1.0000
# normal-pylorus      1.0000
# normal-z-line       0.9200
# polyps              0.9600
# ulcerative-colitis  0.9800
#
# Specificity per classe:
# dyed-lifted-polyps  0.9971
# dyed-resection-margins0.9857
# esophagitis         0.9886
# normal-cecum        1.0000
# normal-pylorus      0.9971
# normal-z-line       0.9771
# polyps              0.9971
# ulcerative-colitis  0.9971
#
# Report salvato in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/Test_classification_report5_exp2.txt
# ROC Curve salvata in: experiments/2.3.2.Swin_class+seg_NOconcatenazione_dataset(run_binary_training)_val+test_seg/Test_roc_curve5_exp2.png

# %%
device = args["device"]
model_path = os.path.join(args['save_dir'], 'model_best_val_bin+multi_exp2.pt')
model.load_state_dict(torch.load(model_path, map_location=device))
model = model.to(device)

hook = model.head[4].register_forward_hook(hook_fn)

# Ottieni le labels e le features dal modello
labels, features = validate_tsne(model, val_loader, device)

# Nomi delle classi (puoi modificare questo elenco in base alle tue classi)
class_names = ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']

# Visualizza il t-SNE plot con legenda
plot_tsne(features, labels, class_names)
# Out:
# Start validation...
# 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
